# %% [markdown]
# ![](data_code_logo.jpg)
#
# <br>
#
# # <span style="color:#ffa500 ">&#9733; AFD Country </span><span style="color:#a8c560">Dashboard </span><span style="color:#81b8e2;">Generator &#9733;</span>
#
# This script generates the web pages needed for "AFD Country Dashbaord".
# The way the portal is designed involves 4 different pages - all country specific
# - The **main frame** (*Country Dashboard frame*) which will host the different 3 sections; as shown below.
#
# The 3 following section are the ones hosting the dataviz:
# - The **eco section**
# - The **DHD section**
# - and the **Institution section**
# <br>
# <span style="color:red">
# <b>To do list</b><br>
#
# </span>

# %% [markdown]
# ## Country Dashboard frame
#
# This script generates the frame that will host Country dashdoards 3 dimensions (Eco, DDH, Inst)
#
# ![](Country_dashboard_frame/frame0.png)

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_frame")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_frame")


#all
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']


#loop over iso3 list#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}

#create an empty string
country=""
for iso3 in isolist:

    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            country=cname
            
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'country':country}
    
    #Starting HTML code
    html='''
<!DOCTYPE html>
<html>
<head>
    <meta http-equiv="content-type" content="text/html; charset=UTF-8">
    <script type="text/javascript" src="jquery.min.js"></script> 
    <link rel="stylesheet" type="text/css" href="/../../font-awesome-4.5.0/css/font-awesome.css">
    <link rel="stylesheet" type="text/css" href="OpenSans.css">
    
    <title>data.afd.fr</title>
    <link rel="icon" href="../../favicon_afd.ico" type="image/x-icon">
 
<style type="text/css">

@font-face {
  font-family: 'Glyphicons Halflings';
  src: url(../../bootstrap-3.3.7-dist/fonts/glyphicons-halflings-regular.eot);
  src: url(../../bootstrap-3.3.7-dist/fonts/glyphicons-halflings-regular.eot?#iefix) format('embedded-opentype'), url(../../bootstrap-3.3.7-dist/fonts/glyphicons-halflings-regular.woff2) format('woff2'), url(../fonts/glyphicons-halflings-regular.woff) format('woff'), url(../fonts/glyphicons-halflings-regular.ttf) format('truetype'), url(../../bootstrap-3.3.7-dist/fonts/glyphicons-halflings-regular.svg#glyphicons_halflingsregular) format('svg')
}

.glyphicon {
  position: relative;
  top: 1px;
  display: inline-block;
  font-family: 'Glyphicons Halflings';
  font-style: normal;
  font-weight: 400;
  line-height: 1;
  -webkit-font-smoothing: antialiased;
  -moz-osx-font-smoothing: grayscale;
}

.glyphicon-home:before {
  content: "\e021"
}    
 
.header_custom {
    position: fixed;
    left: 0;
    top:0;
    right: 0;
    line-height: 6px;
    padding-bottom: 0;
    background-color: white;
    height:65px;
    padding-bottom:6px;
    z-index: 15;
}

   

.head_img_custom  {
    text-align: center;
    padding-top:2px;
    width:100%;  
 }
 .active  {
      color: white;
      cursor: pointer;
      cursor: hand;
    }
    .activeRect{
      background-color: #a6cd61;
    }
        
  .normal {
      background-color: #EEEEEE;
      color: black;
        }
    
    /*Change the icon in the box*/ 
    #box1:hover .parent-box{
      color: white;
      background-color: #a6cd61;
      cursor: pointer;
      cursor: hand;
    }
    /*change the color of the rect and the color of the text*/
    #box1:hover .rect {
      color: white;
      background-color: #a6cd61;
      cursor: pointer;
      cursor: hand;    
    }
    
    #box2:hover .rect2 {
      background-color: #a6cd61;
      cursor: pointer;
      cursor: hand;
      color: white;
    }
   
    #box2:hover .parent-box {
      background-color: #a6cd61;
      cursor: pointer;
      cursor: hand;
      color: white;
    }
    
   
    #box3:hover .rect3 {
      background-color: #a6cd61;
      cursor: pointer;
      cursor: hand;
      color: white;
    }
   
    #box3:hover .parent-box {
      background-color: #a6cd61;
      cursor: pointer;
      cursor: hand;
      color: white;
    }
    
    #rect3 {
      z-index: -1;
      border-radius: 15px;
      margin-top: 175px;
      padding: 20px;
      width: 170px;
      height: 80px;
      position: absolute;
      text-align: center;
      font-size: 17px;
      line-height: 20px;
      font-family: 'Open Sans', 'Helvetica', arial, sans-serif;
    }
    
    #rect2 {
      z-index: -1;
      margin-left: 220px;
      margin-top: 175px;
      border-radius: 10px;
      padding: 20px;
      width: 170px;
      height: 80px;
       position: absolute;
      text-align: center;
      font-size: 17px;
      line-height: 20px;
      font-family: 'Open Sans', 'Helvetica', arial, sans-serif;
    }
    
    #rect {
      z-index: -1;
      margin-left: 440px;
      margin-top: 175px;
      border-radius: 10px;
      padding: 20px;
      width: 170px;
      height: 80px;
      position: absolute;
      text-align: center;
      font-size: 17px;
      line-height: 20px;
      font-family: 'Open Sans', 'Helvetica', arial, sans-serif;
    }
    
    #scale {
      margin-top: 245px;
      margin-left: 523px;
      position: absolute;
      width: 80px;
      height: 75px;
      -webkit-text-stroke: 1px #EEEEEE;
    }
    
    #cap {
      margin-top: 245px;
      margin-left: 305px;
      position: absolute;
      width: 80px;
      height: 75px;
      -webkit-text-stroke: 1px #EEEEEE;
    }
    
    #hos {
      margin-top: 245px;
      margin-left: 370px;
      position: absolute;
      width: 80px;
      height: 75px;
      -webkit-text-stroke: 1px #EEEEEE;
    }
    
    #globe {
      margin-top: 245px;
      margin-left: 250px;
      position: absolute;
      width: 80px;
      height: 75px;
      -webkit-text-stroke: 1px #EEEEEE;
    }
    
    #eco {
      margin-top: 245px;
      margin-left: 85px;
      position: absolute;
      width: 80px;
      height: 75px;
      -webkit-text-stroke: 1px #EEEEEE;
    }
    
    #dashboard {
      margin-top: 70px;
      padding: 20px;
      position: relative
    }
    
    .menu {
      margin-left: 15%;
      margin-top: 0px;
      width: 84%;
      height: 8%;
      position: absolute;
    }
    
    .logo {
      margin-top: 0%;
      margin-left: 0%;
      width: 7%;
      position: absolute;
    }
    
    ul {
      list-style-type: none;
      margin: 0;
      padding: 0;
      overflow: hidden;
      background-color: #EC635A;
      font-family: 'Open Sans', 'Helvetica', arial, sans-serif;
      font-weight: bold;
      height: 60px;
      line-height: 30px;
      font-size: 20px;
      color: white;
    }
    
    li {
      float: left;
    }
    
    li a {
      display: block;
      color: #f9c3c0;
      text-align: center;
      padding: 14px 16px;
      text-decoration: none;
    }
    
    li a:hover:not(.active) {
      color: white;
      cursor: pointer;
      cursor: hand;
    }
    
    .about {
      background-color: #F0847D;
      float: right;
    }
    
    .mainframe {
      z-index: -3;
      width: 98%;
      margin-left: 0px;
      margin-top: 225px;
      position: absolute;
    }
    
    #menu_theme {
      margin-left: 32%;
      margin-top: -95px;
      position: absolute;
    }
    
    .title {
      font-family: "Berlin Sans FB";
      font-size: 42px;
      color: #FFA500;
      margin-top: 40px;
      position: absolute;
      margin-left: 30%;
    }
    
    .frame_css {
      width: 95%;
      height: 14000px;
      margin-left: 3%;
      margin-top: 225px;
      position: absolute
    }
    
 .header_hr {
    border: 0;
    height: 0;
    border-top: 1px solid rgba(0, 0, 0, 0.1);
    border-bottom: 1px solid rgba(255, 255, 255, 0.3);
 }   
     </style>
    
    <title></title>
    <script type='text/javascript'>

    $(window).load(function(){

        $("#rect3").addClass('normal');
        $("#rect2").addClass('normal');
        $("#rect").addClass('normal');

        $('#frame').html('<iframe src="Dashboard$iso3-eco.html" width="100%" height="100%" frameborder="0"></iframe>');

         $("#box3").click(function(e) {
           e.preventDefault();
           $('#frame').html('<iframe src="Dashboard$iso3-eco.html" width="100%" height="100%" frameborder="0"></iframe>');
           $(this).addClass('active');
           $("#rect3").addClass('activeRect');
           $("#rect3").removeClass('normal');

           $("#rect2").addClass('normal');
           $("#rect").addClass('normal');
           $("#box2").removeClass('active');
           $("#rect2").removeClass('activeRect');
           $("#box1").removeClass('active');
           $("#rect").removeClass('activeRect');
         });

         $("#box2").click(function(e) {
           e.preventDefault();
           $('#frame').html('<iframe src="Dashboard$iso3-DHD.html" width="100%" height="100%" frameborder="0"></iframe>');
           $(this).addClass('active');
           $("#rect2").addClass('activeRect');
           $("#rect2").removeClass('normal');

           $("#rect3").addClass('normal');
           $("#rect").addClass('normal');
           $("#box3").removeClass('active');
           $("#rect3").removeClass('activeRect');
           $("#box1").removeClass('active');
           $("#rect").removeClass('activeRect');
         });

         $("#box1").click(function(e) {
           e.preventDefault();
           $('#frame').html('<iframe src="Dashboard$iso3-inst.html" width="100%" height="100%" frameborder="0"></iframe>');
           $(this).addClass('active');
           $("#rect").addClass('activeRect');
           $("#rect").removeClass('normal');

           $("#rect2").addClass('normal');
           $("#rect3").addClass('normal');
           $("#box2").removeClass('active');
           $("#rect2").removeClass('activeRect');
           $("#box3").removeClass('active');
           $("#rec3").removeClass('activeRect');
         });

    });
    </script>
    </head>
    <body>
  
<!--------------------------------------- HEADER ---------------------------------------------------->
<header class="header_custom">
<div style="position: absolute; margin-top:15px; margin-left:15px;"><a href="https://www.dataspace.fr" title="Home"><span class="glyphicon glyphicon-home" style="font-size:1.75em; color:#273B77"></span></a></div>
    <div class="head_img_custom">   
        <a href="http://www.afd.fr" target="_self"><img src="../../header AFD.svg" style="height:56px; width:100%"></a> 
        <hr class="header_hr">
    </div>
</header>
    
<!----------------------------------------- FLAT ---------------------------------------------------------->
<div class="flat">  </div>
        <div id="menu_theme">
          <div>
            <div id="box1">
              <p id="rect" class="rect">Environnement Institutionnel</p>
                <div id="" class="parent-box">
                  <i id="scale" class="fa fa-balance-scale" style="font-size:40px"></i>
                </div>
              
            </div>

          </div>

          <div>
            <div id="box2">
              <p id="rect2" class="rect2">D&#233;veloppement Humain Durable</p>
                <div id="" class="parent-box">
                  <i id="cap" class="fa fa-graduation-cap " style="font-size:35px;"></i>
                  <i id="hos" class="fa fa-hospital-o" style="font-size:35px;"></i>
                  <i id="globe" class="fa fa-leaf" style="font-size:35px;"></i>
                </div>
           
            </div>

          </div>

          <div>
            <div id="box3">
              <p id="rect3" class="rect3">Environnement Economique</p>
                <div id="" class="parent-box">
                  <i id="eco" class="fa fa-line-chart" style="font-size:40px;"></i>
                </div>
             
            </div>

          </div>

        </div>

        <div id="frame" class="frame_css"></div>

    </body>
    </html>
    '''
    #open an handle
    with codecs.open('Country_dashboard'+iso3+'.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Country_dashboard'+iso3+'.html'
    
print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# # 1. Dashboard <span style="color: #FFA500;"> Economic section</span>
# ![](Country_dashboard_frame/eco.png)
#
# #### 1.1 Vertical (V1)

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_eco")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_eco")

#all
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

isolist=['HKG']
#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}
map_dict= {"AGO":"_africa","BFA":"_africa","BDI":"_africa","BEN":"_africa","BWA":"_africa","COD":"_africa","CAF":"_africa","COG":"_africa","CIV":"_africa","CMR":"_africa","CPV":"_africa","DJI":"_africa","DZA":"_africa","EGY":"_africa","ERI":"_africa","ETH":"_africa","GAB":"_africa","GHA":"_africa","GMB":"_africa","GIN":"_africa","GNQ":"_africa","GNB":"_africa","KEN":"_africa","COM":"_africa","LBR":"_africa","LSO":"_africa","LBY":"_africa","MAR":"_africa","MDG":"_africa","MLI":"_africa","MRT":"_africa","MUS":"_africa","MWI":"_africa","MOZ":"_africa","NAM":"_africa","NER":"_africa","NGA":"_africa","RWA":"_africa","SYC":"_africa","SDN":"_africa","SLE":"_africa","SEN":"_africa","SOM":"_africa","SSD":"_africa","STP":"_africa","SXM":"_africa","SWZ":"_africa","TCD":"_africa","TGO":"_africa","TUN":"_africa","TZA":"_africa","UGA":"_africa","ZAF":"_africa","ZMB":"_africa","ZWE":"_africa","ARE":"_asia","AFG":"_asia","ARM":"_asia","AZE":"_asia","BGD":"_asia","BHR":"_asia","BRN":"_asia","BTN":"_asia","CHN":"_asia","HKG":"_asia","CYP":"_asia","GEO":"_asia","IDN":"_asia","ISR":"_asia","IND":"_asia","IRQ":"_asia","IRN":"_asia","JOR":"_asia","JPN":"_asia","KGZ":"_asia","KHM":"_asia","PRK":"_asia","KOR":"_asia","KWT":"_asia","KAZ":"_asia","LAO":"_asia","LBN":"_asia","LKA":"_asia","MMR":"_asia","MNG":"_asia","MYS":"_asia","NCL":"_asia","NPL":"_asia","OMN":"_asia","PHL":"_asia","PAK":"_asia","QAT":"_asia","RUS":"_asia","SAU":"_asia","SGP":"_asia","SHN":"_asia","SYR":"_asia","THA":"_asia","TJK":"_asia","TLS":"_asia","TKM":"_asia","TUR":"_asia","TWN":"_asia","UZB":"_asia","VNM":"_asia","YEM":"_asia","SAU":"_middle_east","YEM":"_middle_east","TUR":"_middle_east","SYR":"_middle_east","QAT":"_middle_east","OMN":"_middle_east","LBN":"_middle_east","KWT":"_middle_east","JOR":"_middle_east","IRN":"_middle_east","IRQ":"_middle_east","ISR":"_middle_east","EGY":"_middle_east","CYP":"_middle_east","BHR":"_middle_east","ARE":"_middle_east","USA":"_north_america","TTO":"_north_america","SLV":"_north_america","PRI":"_north_america","PAN":"_north_america","NIC":"_north_america","MEX":"_north_america","JAM":"_north_america","HTI":"_north_america","GTM":"_north_america","DOM":"_north_america","CUB":"_north_america","CRI":"_north_america","CAN":"_north_america","BLZ":"_north_america","TUR":"_europe","SVK":"_europe","SVN":"_europe","SWE":"_europe","RUS":"_europe","SRB":"_europe","ROU":"_europe","PRT":"_europe","POL":"_europe","NOR":"_europe","NLD":"_europe","MKD":"_europe","MNE":"_europe","MDA":"_europe","LVA":"_europe","LUX":"_europe","LTU":"_europe","ITA":"_europe","ISL":"_europe","IRL":"_europe","HUN":"_europe","HRV":"_europe","GRC":"_europe","GBR":"_europe","FRA":"_europe","FIN":"_europe","ESP":"_europe","EST":"_europe","DNK":"_europe","DEU":"_europe","CZE":"_europe","CYP":"_europe","CHE":"_europe","BLR":"_europe","BGR":"_europe","BEL":"_europe","BIH":"_europe","AUT":"_europe","ALB":"_europe","BRA":"_south_america","VEN":"_south_america","URY":"_south_america","SUR":"_south_america","PRY":"_south_america","PER":"_south_america","GUY":"_south_america","GBR":"_south_america","ECU":"_south_america","COL":"_south_america","CHL":"_south_america","BOL":"_south_america","ARG":"_south_america","ABW":"_south_america", "IDN":"_oceania","PHL":"_oceania","NZL":"_oceania","MYS":"_oceania","AUS":"_oceania"}

#create an empty string
country=""

#loop over iso3 list
for iso3 in isolist:
    
    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            country=cname
            
    for iso,mapregion in map_dict.items(): 
        if iso==iso3: 
            mapext=mapregion
    
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'country':country, 'mapext':mapext}
    
    #Starting HTML code
    html0='''
    <!DOCTYPE html>
    <html>
    <title>Dashboard eco</title>
    <meta http-equiv="content-type" content="text/html; charset=UTF-8">
    <script type="text/javascript" src="jquery.min.js"></script> 
    <link rel="stylesheet" type="text/css" href="/../../font-awesome-4.5.0/css/font-awesome.css">
    <link rel="stylesheet" type="text/css" href="OpenSans.css">    
    <script src="require.min.js"></script>
    <link rel="stylesheet" href="Dashboard.css">
    </head>
    
    <style>

    .left {
    margin-left:-1%;
    width:50%;
    height:100%;
    display: inline-block;
    overflow: hidden;
    }

    .right{
    height:100%;
    width:50%;
    margin-right:-2%;
    display: inline-block;
    overflow: hidden;
    }

    .line{
     display: inline-block;
     overflow: hidden;
     width:80%;
     }
        
    .frame_square{
        border:0;width:100%; height:500px;padding:2px; overflow: hidden;
        }
    
    .frame_rect{
        border:0;width:100%; height:550px;padding:2px; overflow: hidden; 
        }
        
     .frame_map{
     border:0;width:100%; height:550px;padding:2px; overflow: hidden;
     }  
    
    th, td {
       text-align:left;
       font-family:'open-sans';
        width: 50%;
      }
        
    </style>
    '''
    
    html='''  
    <body>
    <div tabindex="-1" id="notebook" class="border-box-sizing">
    <div class="container" id="notebook-container">
    <div class="cell border-box-sizing text_cell rendered">
    <div class="inner_cell">
    <div class="text_cell_render border-box-sizing rendered_html">
    <p></p>

    <h1 id="Environnement-Economique:--$country-"><span style="color: #FFA500;  font-family:'Open Sans' !important;">
    Environnement Economique:     </span><span style="color: #fcc86f;  font-family:'Open Sans' !important;">$country</span></h1>
    <br>
    <hr style="border: 0 !important; height: 0 !important;  border-top: 1px solid rgba(0, 0, 0, 0.1)!important;">
    <h1 ><span style="color:#A8C560;  font-family:'Open Sans' !important;">Sommaire</span></h1>

    <table span style="font-family:'Open Sans' !important; margin-left:40px; width:850px">
    <tr><th span style="font-family:'Open Sans' !important;">Indicateurs Macro&#233;conomiques </th>
    <th span style="font-family:'Open Sans' !important;">Structure de l'&#233;conomie</th></tr><tr>
    <td span style="font-family:'Open Sans' !important;"><a href="#Revenu">Revenu</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#D&#233;composition-de-la-valeur-ajout&#233;e-par-secteur">D&#233;composition de la valeur ajout&#233;e par secteur</a></td></tr>
    <tr><td span style="font-family:'Open Sans' !important;"><a href="#Inflation">Inflation</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Investissment">Investissment</a></td></tr><tr>
    <td span style="font-family:'Open Sans' !important;"><a href="#Balance-courante">Balance courante</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Cr&#233;dit-domestique">Cr&#233;dit domestique</a></td></tr><tr>
    <td span style="font-family:'Open Sans' !important;"><a href="#Evolution-du-taux-de-change">Evolution du taux de change</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Taxes">Taxes</a></td></tr><tr>
    <td span style="font-family:'Open Sans' !important;"><a href="#Recettes-et-d&#233;penses-publiques">Recettes, d&#233;penses et dettes publiques</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Les-&#233;changes-">Les &#233;changes</a></td></tr><tr>
    <td span style="font-family:'Open Sans' !important;"><a href="#-Pauvret&#233;-et-march&#233;-du-travail--">Pauvret&#233; et march&#233; du travail</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Importation-d'&#233;nergie">Importation d'&#233;nergie</a></td></tr><tr>
    <td span style="font-family:'Open Sans' !important;"><a href="#-Perceptions-des-populations-sur-la-sant&#233;-&#233;conomique--">Perceptions des populations sur la sant&#233; &#233;conomique</a></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Acc&#232;s-&#224;-l'eau-et-l'&#233;lectricit&#233;">Acc&#232;s &#224; l'eau et l'&#233;lectricit&#233;</a></td></tr><tr>
        <td></td>
    <td span style="font-family:'Open Sans' !important;"><a href="#Téléphonie-mobile-et-internet">T&#233;l&#233;phonie mobile et internet</a></td></tr>
    </table>
<hr  style="border: 0 !important; height: 0 !important;  border-top: 1px solid rgba(0, 0, 0, 0.1)!important;">

    <h2 id="1.-Indicateurs-Macro&#233;conomiques-"><span style="color:#336D9D;  font-family:'Open Sans'">1. Indicateurs Macro&#233;conomiques </span><a class="anchor-link" href="#1.-Indicateurs-Macro&#233;conomiques-">&#182;</a></h2>
    <hr  style="border: 0 !important; height: 0 !important;  border-top: 1px solid rgba(0, 0, 0, 0.1)!important;">

    <h4 id="Revenu" span style="font-family:'Open Sans'">Revenu<a class="anchor-link" href="#Revenu">&#182;</a></h4>

      <div class="left"><iframe src="../../dataviz/TimeSerie_NY_GDP_MKTP_KD_ZG_$iso3.html" class="frame_square" ></iframe></div>
      <div class="right"><iframe src="../../dataviz/map_NY_GDP_MKTP_KD_ZG$mapext.html" class="frame_map"></iframe></div>
    <br>

    <hr style="border: 0 !important; height: 0 !important;  border-top: 1px solid rgba(0, 0, 0, 0.1)!important;">
    <h4 id="Evolution-de-long-terme-du-revenu-par-habitant" span style="font-family:'Open Sans'">Evolution de long terme du revenu par habitant<a class="anchor-link" href="#Evolution-de-long-terme-du-revenu-par-habitant">&#182;</a></h4>

      <iframe src="../../dataviz/TimeSerie_NY_GDP_PCAP_PP_KD_$iso3.html" class="frame_rect"></iframe><br>

    <hr  style="border: 0; height: 0;  border-top: 1px solid rgba(0, 0, 0, 0.1);">
    <h4 id="Convergence-vers-les-moyennes:-mondiale,-regionale-et-des-pays-aux-revenus-similaires" span style="font-family:'Open Sans'">Convergence vers les moyennes: mondiale, regionale et des pays aux revenus similaires<a class="anchor-link" href="#Convergence-vers-les-moyennes:-mondiale,-regionale-et-des-pays-aux-revenus-similaires">&#182;</a></h4>

      <iframe src="../../dataviz/Convergance_NY_GDP_PCAP_PP_KD_$iso3.html" class="frame_rect"></iframe><br>
    <hr  style="border: 0; height: 0;  border-top: 1px solid rgba(0, 0, 0, 0.1);">

    <h4 id="Inflation" span style="font-family:'Open Sans'">Inflation<a class="anchor-link" href="#Inflation">&#182;</a></h4>

      <iframe src="../../dataviz/TimeSerie_PCPIPCH_$iso3.html" class="frame_rect"></iframe><br>

    <hr class="header_hr">
    <h4 id="Balance-courante" span style="font-family:'Open Sans'">Balance courante<a class="anchor-link" href="#Balance-courante">&#182;</a></h4>

    <iframe src="../../dataviz/TimeSerie_BCA_NGDPD_&_GGXCNL_NGDP_$iso3.html" class="frame_rect"></iframe><br>

    <hr>
    <h4 id="Evolution-du-taux-de-change" span style="font-family:'Open Sans'">Evolution du taux de change<a class="anchor-link" href="#Evolution-du-taux-de-change">&#182;</a></h4>

    <iframe src="../../dataviz/TimeSerie_PA_NUS_FCRF_$iso3.html" class="frame_rect"></iframe><br>

    <hr>
    <h4 id="Recettes-et-d&#233;penses-publiques" span style="font-family:'Open Sans'">Recettes, d&#233;penses et dettes publiques<a class="anchor-link" href="#Recettes-et-d&#233;penses-publiques">&#182;</a></h4>

      <div class="left"><iframe src="../../dataviz/TimeSerie_GGR_NGDP_&_GGX_NGDP_$iso3.html" class="frame_square"></iframe></div>
      <div class="right"><iframe src="../../dataviz/TimeSerie_GGXWDG_NGDP_$iso3.html"class="frame_square"></iframe></div>
        <br>

    <hr>
    <h3 id="-Pauvret&#233;-et-march&#233;-du-travail--" span style="font-family:'Open Sans'"><span style="color: #A8C560"> Pauvret&#233; et march&#233; du travail  </span><a class="anchor-link" href="#-Pauvret&#233;-et-march&#233;-du-travail--">&#182;</a></h3>
    <h4 id="Pauvret&#233;-mon&#233;taire" span style="font-family:'Open Sans'">Pauvret&#233; mon&#233;taire<a class="anchor-link" href="#Pauvret&#233;-mon&#233;taire">&#182;</a></h4>

      <iframe src="../../dataviz/Radar_Pauvret%C3%A9_$iso3.html" class="frame_rect"></iframe><br>

    <h4 id="March&#233;-du-travail:-ch&#244;mage-et-participation-des-femmes" span style="font-family:'Open Sans'">March&#233; du travail: ch&#244;mage et participation des femmes<a class="anchor-link" href="#March&#233;-du-travail:-ch&#244;mage-et-participation-des-femmes">&#182;</a></h4>

    <iframe src="../../dataviz/TimeSerie_SL_UEM_TOTL_ZS_$iso3.html" class="frame_rect"></iframe><br>
    <hr>

    <div class="left"><iframe src="../../dataviz/TimeSerie_SL_UEM_TOTL_FE_ZS_&_SL_UEM_TOTL_MA_ZS_$iso3.html" class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/TimeSerie_SL_EMP_INSV_FE_ZS_&_SL_TLF_CACT_FE_ZS_$iso3.html" class="frame_square"></iframe></div>

    <hr>

    <h3 id="-Perceptions-des-populations-sur-la-sant&#233;-&#233;conomique--"><span style="color: #A8C560; font-family:'Open Sans'"> Perceptions des populations sur la sant&#233; &#233;conomique  </span><a class="anchor-link" href="#-Perceptions-des-populations-sur-la-sant&#233;-&#233;conomique--">&#182;</a></h3>

    <h4 id="Perceptions-sur-les-persepectives-&#233;conmiques-locales-et-nationales" span style="font-family:'Open Sans'">Perceptions sur les persepectives &#233;conmiques locales et nationales<a class="anchor-link" href="#Perceptions-sur-les-persepectives-&#233;conmiques-locales-et-nationales">&#182;</a></h4>

      <div class="left"><iframe src="../../dataviz/GWP/TimeSerie_Conditions%20Economiques_$iso3.html" style="border:0;width:450px; height:550px; padding:2px; overflow: hidden;" frameborder="0"></iframe>
      </div>
      <div class="right"><iframe src="../../dataviz/GWP/map_National%20Economy%20Getting%20Better$mapext.html" class="frame_map"></iframe>
      </div>
    <hr>

    <h2 id="2.-Structure-de-l'&#233;conomie"><span style="color:#336D9D ;font-family:'Open Sans'">2. Structure de l'&#233;conomie</span><a class="anchor-link" href="#2.-Structure-de-l'&#233;conomie">&#182;</a></h2>
    <hr>
    <h4 id="D&#233;composition-de-la-valeur-ajout&#233;e-par-secteur" span style="font-family:'Open Sans'">D&#233;composition de la valeur ajout&#233;e par secteur<a class="anchor-link" href="#D&#233;composition-de-la-valeur-ajout&#233;e-par-secteur">&#182;</a></h4>
    <iframe src="../../dataviz/Radar_Part%20des%20secteurs%20dans%20le%20PIB_$iso3.html" class="frame_rect"></iframe><br>

    <hr>
    <h4 id="Investissment" span style="font-family:'Open Sans'">Investissment<a class="anchor-link" href="#Investissment">&#182;</a></h4>
    <iframe src="../../dataviz/TimeSerie_NID_NGDP_$iso3.html" class="frame_rect"></iframe>
    <br>
    <hr>

    <h4 id="Cr&#233;dit-domestique" span style="font-family:'Open Sans'">Cr&#233;dit domestique<a class="anchor-link" href="#Cr&#233;dit-domestique">&#182;</a></h4>

    <div class="left"><iframe src="../../dataviz/TimeSerie_FM_AST_DOMS_CN_$iso3.html"class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/TimeSerie_FS_AST_PRVT_GD_ZS_$iso3.html"class="frame_square"></iframe></div>
    <hr>

    <h4 id="Taxes" span style="font-family:'Open Sans'">Taxes<a class="anchor-link" href="#Taxes">&#182;</a></h4>
    <iframe src="../../dataviz/TimeSerie_GC_TAX_TOTL_GD_ZS_$iso3.html" class="frame_rect"></iframe>
    <br>

    <hr>
    <h3 id="Les-&#233;changes-"><span style="color: #A8C560; font-family:'Open Sans'">Les &#233;changes </span><a class="anchor-link" href="#Les-&#233;changes-">&#182;</a></h3>
    <h4 id="Les-produits-export&#233;s-(gauche)-et-import&#233;s-(droite)" span style="font-family:'Open Sans'">Les produits export&#233;s (gauche) et import&#233;s (droite)<a class="anchor-link" href="#Les-produits-export&#233;s-(gauche)-et-import&#233;s-(droite)">&#182;</a></h4>

      <div class="left"><iframe src="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/$iso3/all/show/2015/" style="border:0; width:104%; height:395px;overflow: hidden;" frameborder="0"></iframe>
        <br>
        <a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/$iso3/all/show/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
      </div>

      <div class="right"><iframe src="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/$iso3/all/show/2015/" style="border:0; width:104%; height:395px; overflow: hidden; top:0; left: 0; padding:12px 0 0 12px; display:block;" frameborder="0"></iframe>
        <br>
        <a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/$iso3/all/show/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
      </div>

    <h4 id="Origines-des-produits-import&#233;s(gauche)-et-destinations-des-produits-export&#233;s-(droite)" span style="font-family:'Open Sans'">Origines des produits import&#233;s(gauche) et destinations des produits export&#233;s (droite)<a class="anchor-link" href="#Origines-des-produits-import&#233;s(gauche)-et-destinations-des-produits-export&#233;s-(droite)">&#182;</a></h4>
    

      <div class="left"><iframe src="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/$iso3/show/all/2015/" style="border:0; width:104%; height:395px; overflow: hidden;" frameborder="0"></iframe>
        <br>
        <a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/$iso3/show/all/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
      </div>
      <div class="right"><iframe src="http://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/$iso3/show/all/2015/" style="border:0; width:104%; height:395px; overflow: hidden;" frameborder="0"></iframe>
        <br>
        <a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/$iso3/show/all/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
      </div>
    <hr>

    <h4 id="Importation-d'&#233;nergie" span style="font-family:'Open Sans'">Importation d'&#233;nergie<a class="anchor-link" href="#Importation-d'&#233;nergie">&#182;</a></h4>

    <iframe src="../../dataviz/TimeSerie_EG_IMP_CONS_ZS_$iso3.html" class="frame_square"></iframe><br>

    <hr>
    <h3 id="-Infrastructure-et-num&#233;rique-"><span style="color: #A8C560; font-family:'Open Sans'"> Infrastructure et num&#233;rique </span><a class="anchor-link" href="#-Infrastructure-et-num&#233;rique-">&#182;</a></h3>
    <h4 id="Acc&#232;s-&#224;-l'eau-et-l'&#233;lectricit&#233;" span style="font-family:'Open Sans'">Acc&#232;s &#224; l'eau et l'&#233;lectricit&#233;<a class="anchor-link" href="#Acc&#232;s-&#224;-l'eau-et-l'&#233;lectricit&#233;">&#182;</a></h4>

      <div class="left"><iframe src="../../dataviz/TimeSerie_EG_ELC_ACCS_ZS_&_SH_H2O_SAFE_ZS_$iso3.html" class="frame_square"></iframe></div>
      <div class="right"><iframe src="../../dataviz/map_EG_ELC_ACCS_ZS$mapext.html" class="frame_map"></iframe></div>
    <hr>
    <h4 id="Téléphonie-mobile-et-internet">T&#233;l&#233;phonie mobile et internet<a class="anchor-link" href="Téléphonie-mobile-et-internet">&#182;</a></h4>

      <div class="left"><iframe src="../../dataviz/map_IT_NET_USER_ZS$mapext.html" class="frame_map"></iframe></div>
      <div class="right"><iframe src="../../dataviz/TimeSerie_IT_CEL_SETS_P2_&_IT_NET_USER_P2_$iso3.html" class="frame_square"></iframe></div>

    </div></div></div>
    </div></div>

    </body>
    </html>

    '''
    #open an handle
    with codecs.open('Dashboard'+iso3+'-eco.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = html0+Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Dashboard'+iso3+'-eco.html'

print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# # 1. Dashboard <span style="color: #FFA500;"> Economic section</span>
# ### V2 horizontal

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_eco")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_eco")

isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

isolist=['HKG']

#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}
map_dict= {"AGO":"_africa","BFA":"_africa","BDI":"_africa","BEN":"_africa","BWA":"_africa","COD":"_africa","CAF":"_africa","COG":"_africa","CIV":"_africa","CMR":"_africa","CPV":"_africa","DJI":"_africa","DZA":"_africa","EGY":"_africa","ERI":"_africa","ETH":"_africa","GAB":"_africa","GHA":"_africa","GMB":"_africa","GIN":"_africa","GNQ":"_africa","GNB":"_africa","KEN":"_africa","COM":"_africa","LBR":"_africa","LSO":"_africa","LBY":"_africa","MAR":"_africa","MDG":"_africa","MLI":"_africa","MRT":"_africa","MUS":"_africa","MWI":"_africa","MOZ":"_africa","NAM":"_africa","NER":"_africa","NGA":"_africa","RWA":"_africa","SYC":"_africa","SDN":"_africa","SLE":"_africa","SEN":"_africa","SOM":"_africa","SSD":"_africa","STP":"_africa","SXM":"_africa","SWZ":"_africa","TCD":"_africa","TGO":"_africa","TUN":"_africa","TZA":"_africa","UGA":"_africa","ZAF":"_africa","ZMB":"_africa","ZWE":"_africa","ARE":"_asia","AFG":"_asia","ARM":"_asia","AZE":"_asia","BGD":"_asia","BHR":"_asia","BRN":"_asia","BTN":"_asia","CHN":"_asia","HKG":"_asia","CYP":"_asia","GEO":"_asia","IDN":"_asia","ISR":"_asia","IND":"_asia","IRQ":"_asia","IRN":"_asia","JOR":"_asia","JPN":"_asia","KGZ":"_asia","KHM":"_asia","PRK":"_asia","KOR":"_asia","KWT":"_asia","KAZ":"_asia","LAO":"_asia","LBN":"_asia","LKA":"_asia","MMR":"_asia","MNG":"_asia","MYS":"_asia","NCL":"_asia","NPL":"_asia","OMN":"_asia","PHL":"_asia","PAK":"_asia","QAT":"_asia","RUS":"_asia","SAU":"_asia","SGP":"_asia","SHN":"_asia","SYR":"_asia","THA":"_asia","TJK":"_asia","TLS":"_asia","TKM":"_asia","TUR":"_asia","TWN":"_asia","UZB":"_asia","VNM":"_asia","YEM":"_asia","SAU":"_middle_east","YEM":"_middle_east","TUR":"_middle_east","SYR":"_middle_east","QAT":"_middle_east","OMN":"_middle_east","LBN":"_middle_east","KWT":"_middle_east","JOR":"_middle_east","IRN":"_middle_east","IRQ":"_middle_east","ISR":"_middle_east","EGY":"_middle_east","CYP":"_middle_east","BHR":"_middle_east","ARE":"_middle_east","USA":"_north_america","TTO":"_north_america","SLV":"_north_america","PRI":"_north_america","PAN":"_north_america","NIC":"_north_america","MEX":"_north_america","JAM":"_north_america","HTI":"_north_america","GTM":"_north_america","DOM":"_north_america","CUB":"_north_america","CRI":"_north_america","CAN":"_north_america","BLZ":"_north_america","TUR":"_europe","SVK":"_europe","SVN":"_europe","SWE":"_europe","RUS":"_europe","SRB":"_europe","ROU":"_europe","PRT":"_europe","POL":"_europe","NOR":"_europe","NLD":"_europe","MKD":"_europe","MNE":"_europe","MDA":"_europe","LVA":"_europe","LUX":"_europe","LTU":"_europe","ITA":"_europe","ISL":"_europe","IRL":"_europe","HUN":"_europe","HRV":"_europe","GRC":"_europe","GBR":"_europe","FRA":"_europe","FIN":"_europe","ESP":"_europe","EST":"_europe","DNK":"_europe","DEU":"_europe","CZE":"_europe","CYP":"_europe","CHE":"_europe","BLR":"_europe","BGR":"_europe","BEL":"_europe","BIH":"_europe","AUT":"_europe","ALB":"_europe","BRA":"_south_america","VEN":"_south_america","URY":"_south_america","SUR":"_south_america","PRY":"_south_america","PER":"_south_america","GUY":"_south_america","GBR":"_south_america","ECU":"_south_america","COL":"_south_america","CHL":"_south_america","BOL":"_south_america","ARG":"_south_america","ABW":"_south_america", "IDN":"_oceania","PHL":"_oceania","NZL":"_oceania","MYS":"_oceania","AUS":"_oceania"}

#create an empty string
country=""

#loop over iso3 list
for iso3 in isolist:
    
    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            country=cname
            
    for iso,mapregion in map_dict.items(): 
        if iso==iso3: 
            mapext=mapregion
    
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'country':country, 'mapext':mapext}
    
    #Starting HTML code
    html='''

<!DOCTYPE html>
<html>
<head>
<title>Dashboard eco</title>
<meta http-equiv="content-type" content="text/html; charset=UTF-8">
<script src="require.min.js"></script>
<script src="jquery.min.js"></script>
<link rel="stylesheet" type="text/css" href="../font-awesome-4.5.0/css/font-awesome.min.css">
<link rel="stylesheet" type='text/css' href="../bootstrap-3.3.7-dist/css/bootstrap.min.css">
<link rel="stylesheet" type='text/css' href="Dashboard_hztl.css">
<link rel='stylesheet' type='text/css' href="../OpenSans.css" >
    
<style type="text/css"></style>

<script type="text/javascript">
// site preloader
timeout()
</script>
    
</head>

<body>
<!-- Preloader -->

 <div class="js"> 
        
 <div id="menu_theme">
     
    <div id="box1">
        <p id="rect" class="rect"></p>
        <div id="" class="parent-box">
        <i id="scale" class="fa fa-balance-scale" title="Environnement Institutionnel"></i>
            </div>
        </div>
       
    <div id="box2">
        <p id="rect2" class="rect2"></p>
        <div class="parent-box">
            <i id="cap" class="fa fa-graduation-cap" title="Developpement Humain Durable"></i>
            <i id="hos" class="fa fa-hospital-o" title="Developpement Humain Durable"></i>
            <i id="leaf" class="fa fa-leaf" title="Developpement Humain Durable"></i>
            </div>             
        </div>
          
    <div id="box3">
        <p id="rect3" class="rect3"></p>
        <div id="" class="parent-box">
            <i id="eco" class="fa fa-line-chart" title="Environnement Economique"></i>
            </div>
        </div>
     
    <div id="box4">
        <p id="rect4" class="rect4">
        <i class="fa fa-expand" id="expand" title="Ouvrir en plein &eacute;cran"></i></p>
        </div>
     
     <div id="box5">
        <p id="rect5" class="rect5">
     <i class="fa fa-chevron-left" id="nav-left" title="Reculer"></i>
         </p></div>
     
          <div id="box6">
        <p id="rect6" class="rect6">
     <i class="fa fa-chevron-right" id="nav-right" title="Avancer"></i>
         </p></div>
         
</div>
    
<div id="preloader"></div>  
     
<div class="horizontal-scroll-wrapper  rectangles" id="elementtoScrollToID">
 
<div id="test"> <!-- div to get scrolling position-->
    
    <h1><span style="color: #FFA500; margin-top:30px">Environnement Economique: </span><span style="color: #fcc86f;">$country</span></h1><hr style="width:900px !important; margin-left:0px;">
    <h2><span style="color:#A8C560;">Sommaire</span><hr style="width:900px !important; margin-left:0px;"></h2>
     <br><br>
        <table span style="margin-left:40px; width:850px">
          <tr>
            <th style="font-size:14px">Indicateurs Macro&#233;conomiques </th>
            <th style="font-size:14px">Structure de l'&#233;conomie</th>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorRevenu">Revenu</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorStructure" >D&#233;composition de la valeur ajout&#233;e par secteur</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"id="anchorInflation"><a href="#_">Inflation</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorInvestissement">Investissment</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorBalance">Balance courante</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorCredit">Cr&#233;dit domestique</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorChange">Evolution du taux de change</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorTaxes">Taxes</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorRecette">Recettes, d&#233;penses et dettes publiques</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorEchanges">Les &#233;changes</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorPauvreté">Pauvret&#233; et march&#233; du travail</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorImpEnergie">Importation d'&#233;nergie</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorPerception">Perceptions des populations sur la sant&#233; &#233;conomique</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorEauElec">Acc&#232;s &#224; l'eau et l'&#233;lectricit&#233;</a></td>
          </tr><tr>
            <td></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorTel">T&#233;l&#233;phonie mobile et internet</a></td>
          </tr>
        </table>   
    </div>
    
         
         
<div>
<h3><span style="color:#336D9D;">1. Indicateurs Macro&#233;conomiques</span></h3>
<hr>
<h4>Revenu</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_NY_GDP_MKTP_KD_ZG_$iso3.html" class="frame_square" ></iframe></div>
<div class="right"><iframe src="../dataviz/map_NY_GDP_MKTP_KD_ZG$mapext.html" class="frame_map"></iframe></div>
</div>

<div>
<h4>Evolution de long terme du revenu par habitant</h4>
<iframe src="../dataviz/TimeSerie_NY_GDP_PCAP_PP_KD_$iso3.html" class="frame_rect"></iframe><br>    
</div>
       
<div>
<h4>Convergence vers les moyennes: mondiale, regionale et des pays aux revenus similaires</h4>
<iframe src="../dataviz/Convergance_NY_GDP_PCAP_PP_KD_$iso3.html" class="frame_rect"></iframe><br>
</div>

<div>
<h4>Inflation</h4>
<iframe src="../dataviz/TimeSerie_PCPIPCH_$iso3.html" class="frame_rect"></iframe><br>
</div>

<div>
<h4>Balance courante</h4>
<iframe src="../dataviz/TimeSerie_BCA_NGDPD_&_GGXCNL_NGDP_$iso3.html" class="frame_rect"></iframe><br>
</div>

<div>
<h4>Evolution du taux de change</h4>
<iframe src="../dataviz/TimeSerie_PA_NUS_FCRF_$iso3.html" class="frame_rect"></iframe><br>
</div>

<div>
<h4>Recettes, d&#233;penses et dettes publiques</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_GGR_NGDP_&_GGX_NGDP_$iso3.html" class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/TimeSerie_GGXWDG_NGDP_$iso3.html"class="frame_square"></iframe></div>
</div>

<div>
<h3><span style="color: #A8C560">Pauvret&#233; et march&#233; du travail </span></h3>
<h4>Pauvret&#233; mon&#233;taire</h4>
<iframe src="../dataviz/Radar_Pauvreté_$iso3.html" class="frame_rect"></iframe><br>
</div>
    
<div>
<h4>March&#233; du travail: ch&#244;mage et participation des femmes</h4>
<iframe src="../dataviz/TimeSerie_SL_UEM_TOTL_ZS_$iso3.html" class="frame_rect"></iframe><br>
</div>
    
<div><br><br><br>
<div class="left"><iframe src="../dataviz/TimeSerie_SL_UEM_TOTL_FE_ZS_&_SL_UEM_TOTL_MA_ZS_$iso3.html" class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/TimeSerie_SL_EMP_INSV_FE_ZS_&_SL_TLF_CACT_FE_ZS_$iso3.html" class="frame_square"></iframe></div>
</div>
    
<div>
<h3><span style="color: #A8C560;"> Perceptions des populations sur la sant&#233; &#233;conomique  </span></h3>
<h4>Perceptions sur les persepectives &#233;conmiques locales et nationales</h4>
<div class="left"><iframe src="../dataviz/GWP/TimeSerie_Conditions%20Economiques_$iso3.html" style="border:0;width:450px; height:500px; padding:2px; overflow: hidden;" frameborder="0"></iframe></div>
<div class="right"><iframe src="../dataviz/GWP/map_National%20Economy%20Getting%20Better$mapext.html" class="frame_map"></iframe></div>
</div>

<div>
<h2><span style="color:#336D9D">2. Structure de l'&#233;conomie</span></h2>
<hr>
<h4>D&#233;composition de la valeur ajout&#233;e par secteur</h4>
<iframe src="../dataviz/Radar_Part%20des%20secteurs%20dans%20le%20PIB_$iso3.html" class="frame_rect"></iframe>   
</div>
    
<div> 
<h4>Investissment</h4>
<iframe src="../dataviz/TimeSerie_NID_NGDP_$iso3.html" class="frame_rect"></iframe>
</div>
    
<div>
<h4>Cr&#233;dit domestique</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_FM_AST_DOMS_CN_$iso3.html"class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/TimeSerie_FS_AST_PRVT_GD_ZS_$iso3.html"class="frame_square"></iframe></div>
</div>

<div>
<h4>Taxes</h4>
<iframe src="../dataviz/TimeSerie_GC_TAX_TOTL_GD_ZS_$iso3.html" class="frame_rect"></iframe>
</div>

<div>
<h3><span style="color: #A8C560;">Les &#233;changes </span></h3>
<h4>Les produits export&#233;s</h4>
<div class="frame_rect" style="margin-top: -30px; overflow: hidden !important; border: 0px;"><iframe src="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/AFG/all/show/2015/" width="870" height="480" frameborder="0"></iframe><br>
<a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/AFG/all/show/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
</div>
</div>
    
<div>
<h4>Les produits import&#233;s</h4>
<div class="frame_rect" style="margin-top:0px; overflow: hidden !important; border: 0px;">
    <iframe width="870" height="480" src="http://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/afg/all/show/2015/?controls=false" frameborder="0" ></iframe><br>
<a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/AFG/all/show/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
</div>
</div>
    
<div>
<h4>Origines des produits import&#233;s</h4>
<div class="frame_rect" style="margin-top:0px;overflow: hidden !important;border: 0px;">
<iframe src="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/AFG/show/all/2015/"width="870" height="480" frameborder="0"></iframe><br>
<a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/export/AFG/show/all/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
</div>
    </div>

<div>
<h4> Les destinations des produits export&#233;s</h4>
<div class="frame_rect" style="margin-top:0px; overflow: hidden !important; border: 0px;">
<iframe src="http://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/AFG/show/all/2015/"width="870" height="480" frameborder="0"></iframe><br>
<a href="https://atlas.media.mit.edu/fr/visualize/embed/tree_map/hs92/import/AFG/show/all/2015/" target="_blank" style="font-size: 11px"><i class="fa fa-arrows-alt"></i> Full screen</a>
</div>
</div>

<div>
    <h4>Importation d'&#233;nergie</h4>
    <iframe src="../dataviz/TimeSerie_EG_IMP_CONS_ZS_$iso3.html" class="frame_square"></iframe><br>
    </div>
<div>
    <h3><span style="color: #A8C560;"> Infrastructure et num&#233;rique </span></h3>
    <h4>Acc&#232;s &#224; l'eau et l'&#233;lectricit&#233;</h4>
      <div class="left"><iframe src="../dataviz/TimeSerie_EG_ELC_ACCS_ZS_&_SH_H2O_SAFE_ZS_$iso3.html" class="frame_square"></iframe></div>
      <div class="right"><iframe src="../dataviz/map_EG_ELC_ACCS_ZS$mapext.html" class="frame_map"></iframe></div>
</div>
<div>
    <h4>T&#233;l&#233;phonie mobile et internet</h4>
      <div class="left"><iframe src="../dataviz/map_IT_NET_USER_ZS$mapext.html" class="frame_map"></iframe></div>
      <div class="right"><iframe src="../dataviz/TimeSerie_IT_CEL_SETS_P2_&_IT_NET_USER_P2_$iso3.html" class="frame_square"></iframe></div>
    </div>
    
</div>
    </div>
</body>

</html>


    
    '''
    #open an handle
    with codecs.open('Dashboard'+iso3+'-eco_hztl.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Dashboard'+iso3+'-eco_hztl.html'

print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# ---
#
# # 2. Dashboard <span style="color: #a8c560;"> Développement Humain Durable section</span>
# ![](Country_dashboard_frame/DHD.png)
#
#
# ### 2.1 Vertical Version(v1)

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_DHD")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_DHD")

#all
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

isolist=['HKG']

#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}
map_dict= {"AGO":"_africa","BFA":"_africa","BDI":"_africa","BEN":"_africa","BWA":"_africa","COD":"_africa","CAF":"_africa","COG":"_africa","CIV":"_africa","CMR":"_africa","CPV":"_africa","DJI":"_africa","DZA":"_africa","EGY":"_africa","ERI":"_africa","ETH":"_africa","GAB":"_africa","GHA":"_africa","GMB":"_africa","GIN":"_africa","GNQ":"_africa","GNB":"_africa","KEN":"_africa","COM":"_africa","LBR":"_africa","LSO":"_africa","LBY":"_africa","MAR":"_africa","MDG":"_africa","MLI":"_africa","MRT":"_africa","MUS":"_africa","MWI":"_africa","MOZ":"_africa","NAM":"_africa","NER":"_africa","NGA":"_africa","RWA":"_africa","SYC":"_africa","SDN":"_africa","SLE":"_africa","SEN":"_africa","SOM":"_africa","SSD":"_africa","STP":"_africa","SXM":"_africa","SWZ":"_africa","TCD":"_africa","TGO":"_africa","TUN":"_africa","TZA":"_africa","UGA":"_africa","ZAF":"_africa","ZMB":"_africa","ZWE":"_africa","ARE":"_asia","AFG":"_asia","ARM":"_asia","AZE":"_asia","BGD":"_asia","BHR":"_asia","BRN":"_asia","BTN":"_asia","CHN":"_asia","HKG":"_asia","CYP":"_asia","GEO":"_asia","IDN":"_asia","ISR":"_asia","IND":"_asia","IRQ":"_asia","IRN":"_asia","JOR":"_asia","JPN":"_asia","KGZ":"_asia","KHM":"_asia","PRK":"_asia","KOR":"_asia","KWT":"_asia","KAZ":"_asia","LAO":"_asia","LBN":"_asia","LKA":"_asia","MMR":"_asia","MNG":"_asia","MYS":"_asia","NCL":"_asia","NPL":"_asia","OMN":"_asia","PHL":"_asia","PAK":"_asia","QAT":"_asia","RUS":"_asia","SAU":"_asia","SGP":"_asia","SHN":"_asia","SYR":"_asia","THA":"_asia","TJK":"_asia","TLS":"_asia","TKM":"_asia","TUR":"_asia","TWN":"_asia","UZB":"_asia","VNM":"_asia","YEM":"_asia","SAU":"_middle_east","YEM":"_middle_east","TUR":"_middle_east","SYR":"_middle_east","QAT":"_middle_east","OMN":"_middle_east","LBN":"_middle_east","KWT":"_middle_east","JOR":"_middle_east","IRN":"_middle_east","IRQ":"_middle_east","ISR":"_middle_east","EGY":"_middle_east","CYP":"_middle_east","BHR":"_middle_east","ARE":"_middle_east","USA":"_north_america","TTO":"_north_america","SLV":"_north_america","PRI":"_north_america","PAN":"_north_america","NIC":"_north_america","MEX":"_north_america","JAM":"_north_america","HTI":"_north_america","GTM":"_north_america","DOM":"_north_america","CUB":"_north_america","CRI":"_north_america","CAN":"_north_america","BLZ":"_north_america","TUR":"_europe","SVK":"_europe","SVN":"_europe","SWE":"_europe","RUS":"_europe","SRB":"_europe","ROU":"_europe","PRT":"_europe","POL":"_europe","NOR":"_europe","NLD":"_europe","MKD":"_europe","MNE":"_europe","MDA":"_europe","LVA":"_europe","LUX":"_europe","LTU":"_europe","ITA":"_europe","ISL":"_europe","IRL":"_europe","HUN":"_europe","HRV":"_europe","GRC":"_europe","GBR":"_europe","FRA":"_europe","FIN":"_europe","ESP":"_europe","EST":"_europe","DNK":"_europe","DEU":"_europe","CZE":"_europe","CYP":"_europe","CHE":"_europe","BLR":"_europe","BGR":"_europe","BEL":"_europe","BIH":"_europe","AUT":"_europe","ALB":"_europe","BRA":"_south_america","VEN":"_south_america","URY":"_south_america","SUR":"_south_america","PRY":"_south_america","PER":"_south_america","GUY":"_south_america","GBR":"_south_america","ECU":"_south_america","COL":"_south_america","CHL":"_south_america","BOL":"_south_america","ARG":"_south_america","ABW":"_south_america", "IDN":"_oceania","PHL":"_oceania","NZL":"_oceania","MYS":"_oceania","AUS":"_oceania"}

#create an empty string
country=""

#loop over iso3 list
for iso3 in isolist:
    
    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            Country=cname
            
    for iso,mapregion in map_dict.items(): 
        if iso==iso3: 
            mapext=mapregion
    
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'Country':Country, 'mapext':mapext}
    
    #Starting HTML code
    html0='''
    <!DOCTYPE html>
    <html>
    <head>
    <title>Dashboard DHD</title>
    <meta http-equiv="content-type" content="text/html; charset=UTF-8">
    <script type="text/javascript" src="jquery.min.js"></script> 
    <link rel="stylesheet" type="text/css" href="/../../font-awesome-4.5.0/css/font-awesome.css">
    <link rel="stylesheet" type="text/css" href="OpenSans.css">    
    <script src="require.min.js"></script>
    <link rel="stylesheet" href="Dashboard.css">
    </head>
    
    <style>

    .left {
    margin-left:-1%;
    width:50%;
    height:100%;

     display: inline-block;
     overflow: hidden;
    }

    .right{
    height:100%;
    width:50%;
    margin-right:-2%;

     display: inline-block;
     overflow: hidden;
    }

    .line{
     display: inline-block;
     overflow: hidden;
     width:80%;
     }
        
    .hr{
    width:90% !important;
        }
    
    .frame_square{
        border:0;width:100%; height:500px;padding:2px; overflow: hidden;
        }
    
    .frame_rect{
        border:0;width:100%; height:550px;padding:2px; overflow: hidden; 
        }
        
     .frame_map{
     border:0;width:100%; height:550px;padding:2px; overflow: hidden;
     }   
    
    th, td {
       text-align:left;
       font-family:'open-sans';
        width: 50%;
      }
    </style>
    
    <body>
    <div tabindex="-1" id="notebook" class="border-box-sizing">
    <div class="container" id="notebook-container">
    <div class="cell border-box-sizing text_cell rendered">
    <div class="inner_cell">
    <div class="text_cell_render border-box-sizing rendered_html">
    <p></p>
        
    <h1 id="D&#233;veloppement-Humain-Durable:"><span style="color: #a8c560;font-family:'Open Sans' !important;">D&#233;veloppement Humain Durable:</span> <span style="color: #c1e283;  font-family:'Open Sans' !important;">  </span><a class="anchor-link" href="#D&#233;veloppement-Humain-Durable:-Afghanistan-">&#182;</a></h1>
    <br>
    '''
    
    html='''
    <hr>
 
    <h2><span style="color:#336D9D; font-family:'Open Sans'">1. Energie et environnement</span></h2>
    <hr>
    <h4 id="Consommation-d'&#233;nergie" span style="font-family:'Open Sans'">Consommation d'&#233;nergie<a class="anchor-link" href="#Consommation-d'&#233;nergie">&#182;</a></h4>
   <div class="left"><iframe src="../../dataviz/TimeSerie_EG_USE_COMM_FO_ZS_$iso3.html"  class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/TimeSerie_EG_USE_ELEC_KH_PC_$iso3.html" class="frame_square"></iframe></div>
    <hr>
        
    <h4 id="Energies-alternatives" span style="font-family:'Open Sans'">Energies alternatives<a class="anchor-link" href="#Energies-alternatives">&#182;</a></h4>
    <iframe src="../../dataviz/TimeSerie_EG_USE_COMM_CL_ZS_&_EG_USE_CRNW_ZS_$iso3.html" class="frame_rect"></iframe><br>
    <hr>
        
    <h4 id="Emisions" span style="font-family:'Open Sans'">Emisions<a class="anchor-link" href="#Emisions">&#182;</a></h4>
    <iframe src="../../dataviz/TimeSerie_EN_ATM_CO2E_PC_$iso3.html" class="frame_rect" ></iframe><br>
    <hr>
    <iframe src="../../dataviz/TimeSerie_EN_ATM_GHGO_KT_CE_&_EN_ATM_METH_KT_CE_$iso3.html" class="frame_rect" ></iframe><br>
    <hr>
        
    <h4 id="Perceptions-des-populations" span style="font-family:'Open Sans'">Perceptions des populations<a class="anchor-link" href="#Perceptions-des-populations">&#182;</a></h4>
    <iframe src="../../dataviz/GWP/Radar_Satisfaction%20politique%20environnementale_$iso3.html" class="frame_rect"></iframe><br>
    <hr>
        
    <h3><span style="color:#336D9D; font-family:'Open Sans'">2. Population, sant&#233; et &#233;ducation</span></h3><hr>
    <h3 id="Population:" span style="font-family:'Open Sans'"><span style="color:#FFA500;">Population:</span><a class="anchor-link" href="#Population:">&#182;</a></h3>
    
    <h4 id="Esp&#233;rance-de-vie-&#224;-la-naissance" span style="font-family:'Open Sans'">Esp&#233;rance de vie &#224; la naissance<a class="anchor-link" href="#Esp&#233;rance-de-vie-&#224;-la-naissance">&#182;</a></h4>
    <iframe src="../../dataviz/TimeSerie_SP_DYN_LE00_FE_IN_&_SP_DYN_LE00_MA_IN_$iso3.html" class="frame_rect"></iframe><br>
    <hr>
        
    <h4 id="Distribution de la population" span style="font-family:'Open Sans'">Distribution de la population<a class="anchor-link" href="#Distribution de la population">&#182;</a></h4>
    <iframe src="../../dataviz/Radar_Population par groupe_$iso3.html" class="frame_rect"></iframe><br>
   <hr>
        
    <h4 id="Population-au-niveau-regional" span style="font-family:'Open Sans'">Population au niveau regional<a class="anchor-link" href="#Population-au-niveau-regional">&#182;</a></h4>
    <iframe src="../../dataviz/map_SP_POP_TOTLmapext.html" class="frame_rect"></iframe><br>
    <hr>
        
    <h3 id="-Sant&#233;-et-Education:"><span style="color:#FFA500; font-family:'Open Sans'"> Sant&#233; et Education:</span><a class="anchor-link" href="#-Sant&#233;-et-Education:">&#182;</a></h3>
    <hr>
        
    <h4 id="Evolution-du-taux-d'alphabetisation,-dur&#233;e-d'&#233;tudes-et-enseignants-par-classe" span style="font-family:'Open Sans'">Evolution du taux d'alphabetisation, dur&#233;e d'&#233;tudes et enseignants par classe<a class="anchor-link" href="#Evolution-du-taux-d'alphabetisation,-dur&#233;e-d'&#233;tudes-et-enseignants-par-classe">&#182;</a></h4>
    <div class="left"><iframe src="../../dataviz/TimeSerie_SE_ADT_1524_LT_FE_ZS_&_SE_ADT_1524_LT_MA_ZS_$iso3.html" class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/Radar_Inscriptions des élèves par niveau d'enseignement_$iso3.html" class="frame_square"></iframe></div>
    <hr>
        
    <h4 id="D&#233;penses-de-sant&#233;-et-Protection-sociale" span style="font-family:'Open Sans'">D&#233;penses de sant&#233; et Protection sociale<a class="anchor-link" href="#D&#233;penses-de-sant&#233;-et-Protection-sociale">&#182;</a></h4>
    <div class="left">
    <iframe src="../../dataviz/TimeSerie_SE_XPD_TOTL_GD_ZS_&_SH_XPD_TOTL_ZS_$iso3.html"  class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/Radar_Services sociaux_$iso3.html" class="frame_square"></iframe></div>
    <hr>

    <div class="left"><iframe src="../../dataviz/Radar_Services de santé_$iso3.html" class="frame_rect"></iframe></div>
    <div class="right"><iframe src="../../dataviz/GWP/Radar_Satisfaction%20Ville,%20santé%20et%20éducation_$iso3.html"  class="frame_rect"></iframe>       
    </div>
   
    <hr>
    <h3 id="-Bien-&#234;tre-subjectif-"><span style="color:#FFA500; font-family:'Open Sans'"> Bien-&#234;tre subjectif </span><a class="anchor-link" href="#-Bien-&#234;tre-subjectif-">&#182;</a></h3><hr>
        
    <h4 id="Satisfaction et optimisme des populations" span style="font-family:'Open Sans'">Satisfaction et optimisme des populations<a class="anchor-link" href="#Satisfaction et optimisme des populations">&#182;</a></h4>
   
    <iframe src="../../dataviz/GWP/TimeSerie_Satisfaction%20des%20population%20(0-10)_$iso3.html" class="frame_rect"></iframe>
      
    <hr>
    <h4 id="-Bien-&#234;tre" span style="font-family:'Open Sans'">Bien-&#234;tre subjectif<a class="anchor-link" href="#-Bien-&#234;tre">&#182;</a></h4>

    <iframe src="../../dataviz/GWP/Radar_Bien-être subjectif_$iso3.html"  class="frame_rect"></iframe>
    
  <hr>
    <h4 id="Perception des conditions de travailPerception des conditions de travail" span style="font-family:'Open Sans'">Perception des conditions de travail<a class="anchor-link" href="#Perception des conditions de travail">&#182;</a></h4>
 
    <iframe src="../../dataviz/GWP/Radar_Satisfaction%20au%20travail_$iso3.html" class="frame_rect"></iframe>
    
    </div>
    </div>
    </div>
        </div>
      </div>
    </body>
    </html>
    '''
    #open an handle
    with codecs.open('Dashboard'+iso3+'-DHD.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = html0+Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Dashboard'+iso3+'-DHD.html'

print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# ---
#
# # 2. Dashboard <span style="color: #a8c560;"> Développement Humain Durable section</span>
# ![](Country_dashboard_frame/DHD.png)
#
#
# ### 2.2 Horizontal Version(v2)

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_DHD")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_DHD")

#all
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

isolist=['HKG']

#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}
map_dict= {"AGO":"_africa","BFA":"_africa","BDI":"_africa","BEN":"_africa","BWA":"_africa","COD":"_africa","CAF":"_africa","COG":"_africa","CIV":"_africa","CMR":"_africa","CPV":"_africa","DJI":"_africa","DZA":"_africa","EGY":"_africa","ERI":"_africa","ETH":"_africa","GAB":"_africa","GHA":"_africa","GMB":"_africa","GIN":"_africa","GNQ":"_africa","GNB":"_africa","KEN":"_africa","COM":"_africa","LBR":"_africa","LSO":"_africa","LBY":"_africa","MAR":"_africa","MDG":"_africa","MLI":"_africa","MRT":"_africa","MUS":"_africa","MWI":"_africa","MOZ":"_africa","NAM":"_africa","NER":"_africa","NGA":"_africa","RWA":"_africa","SYC":"_africa","SDN":"_africa","SLE":"_africa","SEN":"_africa","SOM":"_africa","SSD":"_africa","STP":"_africa","SXM":"_africa","SWZ":"_africa","TCD":"_africa","TGO":"_africa","TUN":"_africa","TZA":"_africa","UGA":"_africa","ZAF":"_africa","ZMB":"_africa","ZWE":"_africa","ARE":"_asia","AFG":"_asia","ARM":"_asia","AZE":"_asia","BGD":"_asia","BHR":"_asia","BRN":"_asia","BTN":"_asia","CHN":"_asia","HKG":"_asia","CYP":"_asia","GEO":"_asia","IDN":"_asia","ISR":"_asia","IND":"_asia","IRQ":"_asia","IRN":"_asia","JOR":"_asia","JPN":"_asia","KGZ":"_asia","KHM":"_asia","PRK":"_asia","KOR":"_asia","KWT":"_asia","KAZ":"_asia","LAO":"_asia","LBN":"_asia","LKA":"_asia","MMR":"_asia","MNG":"_asia","MYS":"_asia","NCL":"_asia","NPL":"_asia","OMN":"_asia","PHL":"_asia","PAK":"_asia","QAT":"_asia","RUS":"_asia","SAU":"_asia","SGP":"_asia","SHN":"_asia","SYR":"_asia","THA":"_asia","TJK":"_asia","TLS":"_asia","TKM":"_asia","TUR":"_asia","TWN":"_asia","UZB":"_asia","VNM":"_asia","YEM":"_asia","SAU":"_middle_east","YEM":"_middle_east","TUR":"_middle_east","SYR":"_middle_east","QAT":"_middle_east","OMN":"_middle_east","LBN":"_middle_east","KWT":"_middle_east","JOR":"_middle_east","IRN":"_middle_east","IRQ":"_middle_east","ISR":"_middle_east","EGY":"_middle_east","CYP":"_middle_east","BHR":"_middle_east","ARE":"_middle_east","USA":"_north_america","TTO":"_north_america","SLV":"_north_america","PRI":"_north_america","PAN":"_north_america","NIC":"_north_america","MEX":"_north_america","JAM":"_north_america","HTI":"_north_america","GTM":"_north_america","DOM":"_north_america","CUB":"_north_america","CRI":"_north_america","CAN":"_north_america","BLZ":"_north_america","TUR":"_europe","SVK":"_europe","SVN":"_europe","SWE":"_europe","RUS":"_europe","SRB":"_europe","ROU":"_europe","PRT":"_europe","POL":"_europe","NOR":"_europe","NLD":"_europe","MKD":"_europe","MNE":"_europe","MDA":"_europe","LVA":"_europe","LUX":"_europe","LTU":"_europe","ITA":"_europe","ISL":"_europe","IRL":"_europe","HUN":"_europe","HRV":"_europe","GRC":"_europe","GBR":"_europe","FRA":"_europe","FIN":"_europe","ESP":"_europe","EST":"_europe","DNK":"_europe","DEU":"_europe","CZE":"_europe","CYP":"_europe","CHE":"_europe","BLR":"_europe","BGR":"_europe","BEL":"_europe","BIH":"_europe","AUT":"_europe","ALB":"_europe","BRA":"_south_america","VEN":"_south_america","URY":"_south_america","SUR":"_south_america","PRY":"_south_america","PER":"_south_america","GUY":"_south_america","GBR":"_south_america","ECU":"_south_america","COL":"_south_america","CHL":"_south_america","BOL":"_south_america","ARG":"_south_america","ABW":"_south_america", "IDN":"_oceania","PHL":"_oceania","NZL":"_oceania","MYS":"_oceania","AUS":"_oceania"}

#create an empty string
country=""

#loop over iso3 list
for iso3 in isolist:
    
    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            country=cname
            
    for iso,mapregion in map_dict.items(): 
        if iso==iso3: 
            mapext=mapregion
    
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'country':country, 'mapext':mapext}
    
    #Starting HTML code
    html='''
    
  <!DOCTYPE html>
<html>
<head>
<title>Dashboard eco</title>
<meta http-equiv="content-type" content="text/html; charset=UTF-8">
<script src="require.min.js"></script>
<script src="jquery.min.js"></script>
<link rel="stylesheet" type="text/css" href="../font-awesome-4.5.0/css/font-awesome.min.css">
<link rel="stylesheet" type='text/css' href="../bootstrap-3.3.7-dist/css/bootstrap.min.css">
<link rel="stylesheet" type='text/css' href="Dashboard_hztl.css">
<link rel='stylesheet' type='text/css' href="../OpenSans.css" >
    
<style type="text/css"></style>

<script type="text/javascript">
// site preloader
timeout()
</script>
    
    
</head>

<body>
<!-- Preloader -->
 <div class="js"> 
        
 <div id="menu_theme">
     
    <div id="box1">
        <p id="rect" class="rect"></p>
        <div id="" class="parent-box">
        <i id="scale" class="fa fa-balance-scale" title="Environnement Institutionnel"></i>
            </div>
        </div>
       
    <div id="box2">
        <p id="rect2" class="rect2"></p>
        <div class="parent-box">
            <i id="cap" class="fa fa-graduation-cap" title="Developpement Humain Durable"></i>
            <i id="hos" class="fa fa-hospital-o" title="Developpement Humain Durable"></i>
            <i id="leaf" class="fa fa-leaf" title="Developpement Humain Durable"></i>
            </div>             
        </div>
          
    <div id="box3">
        <p id="rect3" class="rect3"></p>
        <div id="" class="parent-box">
            <i id="eco" class="fa fa-line-chart" title="Environnement Economique"></i>
            </div>
        </div>
     
    <div id="box4">
        <p id="rect4" class="rect4">
        <i class="fa fa-expand" id="expand" title="Ouvrir en plein &eacute;cran"></i></p>
        </div>
     
     <div id="box5">
        <p id="rect5" class="rect5">
     <i class="fa fa-chevron-left" id="nav-left" title="Reculer"></i>
         </p></div>
     
          <div id="box6">
        <p id="rect6" class="rect6">
     <i class="fa fa-chevron-right" id="nav-right" title="Avancer"></i>
         </p></div>
         
</div>
    
<div id="preloader"></div>  
     
<div class="horizontal-scroll-wrapper  rectangles" id="elementtoScrollToID">
 
<div id="test"> <!-- div to get scrolling position-->
    
    <h1><span style="color: #a8c560; margin-top:30px">D&#233;veloppement Humain Durable: </span><span style="color: #c1e283;">$country</span></h1><hr style="width:900px !important; margin-left:0px;">
    <h2><span style="color:#A8C560;">Sommaire</span><hr style="width:900px !important; margin-left:0px;"></h2>
     <br>
    
    <table span style="margin-left:40px; width:850px">
        <tr>
            <th span style="Font-size:14px; !important;">Energie et environnement</th>
        <th span style="font-size:14px; !important;">Population, sant&#233; et &#233;ducation</th></tr><tr>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorEnergie">Consommation d'&#233;nergie</a></td>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorEspVie">Esp&#233;rance de vie a la naissance</a></td></tr>
        <tr>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorEnergieAlt">Energies alternatives</a></td>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorPop">Distribution de la population</a></td></tr><tr>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorEmissions">Emisions</a></td>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorAlphabet">Alphabetisation et scolarit&#233;</a></td></tr>
        <tr>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorPerceptionDHD">Perceptions des populations</a></td>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorBienEtre">Bien-être subjectif</a></td></tr> 
        <tr><td></td>
        <td span style="font-size:14px; font-weight:normal  !important;"><a href="#_" id="anchorSanteProtec">D&#233;penses de sant&#233; et Protection sociale</a></td>
           </tr><tr><td></td>
        <td span style="font-size:14px; font-weight:normal !important;"><a href="#_" id="anchorTravail">Satisfaction, optimisme des populations et conditions de travail</a></td>
        </tr>       
        </table>
    
      </div>
    
         
<div>
<h3><span style="color:#336D9D;">1. Energie et environnement</span></h3>
<hr>
    
<h4>Consommation d'&#233;nergie</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_EG_USE_COMM_FO_ZS_$iso3.html"  class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/TimeSerie_EG_USE_ELEC_KH_PC_$iso3.html" class="frame_square"></iframe></div>
</div>

<div>
<h4>Energies alternatives</h4>
<iframe src="../dataviz/TimeSerie_EG_USE_COMM_CL_ZS_&_EG_USE_CRNW_ZS_$iso3.html" class="frame_rect"></iframe><br>    
</div>
       
<div>
<h4>Emissions</h4>
<iframe src="../dataviz/TimeSerie_EN_ATM_CO2E_PC_$iso3.html" class="frame_rect" ></iframe><br>
</div>

<div>
<h4>Emissions (suite)</h4>
 <iframe src="../dataviz/TimeSerie_EN_ATM_GHGO_KT_CE_&_EN_ATM_METH_KT_CE_$iso3.html" class="frame_rect" ></iframe><br>
</div>

<div>
<h4>Perceptions des populations</h4>
    <iframe src="../dataviz/Radar_Satisfaction%20politique%20environnementale_$iso3.html" class="frame_radar"></iframe><br>
</div>

<div>
<h3><span style="color:#336D9D;">2. Population, sant&#233; et &#233;ducation</span></h3>
<hr>
<h4>Esp&#233;rance de vie &#224; la naissance</h4>
<iframe src="../dataviz/TimeSerie_SP_DYN_LE00_FE_IN_&_SP_DYN_LE00_MA_IN_$iso3.html" class="frame_rect"></iframe>
</div>

<div> 
<h4>Distribution de la population</h4>
<iframe src="../dataviz/Radar_Population par groupe_$iso3.html" class="frame_radar"></iframe><br>
</div>
        
<div>
<h4>Population au niveau regional</h4>
<iframe src="../dataviz/map_SP_POP_TOTL$mapext.html" class="frame_map"></iframe>
</div>

<div>
<h3><span style="color:#FFA500;"> Sant&#233; et Education:</span></h3>
<hr>
<h4>Evolution du taux d'alphabetisation, dur&#233;e d'&#233;tudes et enseignants par classe</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_SE_ADT_1524_LT_FE_ZS_&_SE_ADT_1524_LT_MA_ZS_$iso3.html" class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/Radar_Inscriptions%20des%20élèves%20par%20niveau%20d'enseignement_$iso3.html" class="frame_radar"></iframe></div>
</div>

<div>
<h4>D&#233;penses de sant&#233; et Protection sociale</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_SE_XPD_TOTL_GD_ZS_&_SH_XPD_TOTL_ZS_$iso3.html" class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/Radar_Services%20sociaux_$iso3.html" class="frame_radar"></iframe></div>
</div>
    
<div>
<h4>D&#233;penses de sant&#233; et Protection sociale (suite)</h4>
<div class="left"><iframe src="../dataviz/Radar_Services%20de%20santé_$iso3.html" class="frame_map"></iframe></div>
<div class="right"><iframe src="../dataviz/Radar_Satisfaction%20Ville,%20santé%20et%20éducation_$iso3.html"  class="frame_map"></iframe></div>       
</div>

<div>
<h3><span style="color:#FFA500;"> Bien-&#234;tre subjectif </span></h3>
<hr>      
<h4>Satisfaction et optimisme des populations</h4>
<iframe src="../dataviz/TimeSerie_Satisfaction%20des%20population%20(0-10)_$iso3.html" class="frame_rect"></iframe>
</div>     

<div>   
<h4>Bien-&#234;tre subjectif</h4>
<iframe src="../dataviz/Radar_Bien-etre%20subjectif_$iso3.html"  class="frame_rect"></iframe>
</div>     

<div>
<h4>Perception des conditions de travail</h4>
<iframe src="../dataviz/Radar_Satisfaction%20au%20travail_$iso3.html" class="frame_rect"></iframe>
 </div>
    
    
</div>
    </div>
</body>

</html>


    '''
    #open an handle
    with codecs.open('Dashboard'+iso3+'-DHD_hztl.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Dashboard'+iso3+'-DHD_hztl.html'

print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# ---
#
# # 3. Dashboard <span style="color: #81b8e2;"> Institution section</span>
# ![](Country_dashboard_frame/inst.png)
#
# ### 3.1 vertical v1

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_inst")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_inst")
#all
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

isolist=['HKG']

#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}
map_dict= {"AGO":"_africa","BFA":"_africa","BDI":"_africa","BEN":"_africa","BWA":"_africa","COD":"_africa","CAF":"_africa","COG":"_africa","CIV":"_africa","CMR":"_africa","CPV":"_africa","DJI":"_africa","DZA":"_africa","EGY":"_africa","ERI":"_africa","ETH":"_africa","GAB":"_africa","GHA":"_africa","GMB":"_africa","GIN":"_africa","GNQ":"_africa","GNB":"_africa","KEN":"_africa","COM":"_africa","LBR":"_africa","LSO":"_africa","LBY":"_africa","MAR":"_africa","MDG":"_africa","MLI":"_africa","MRT":"_africa","MUS":"_africa","MWI":"_africa","MOZ":"_africa","NAM":"_africa","NER":"_africa","NGA":"_africa","RWA":"_africa","SYC":"_africa","SDN":"_africa","SLE":"_africa","SEN":"_africa","SOM":"_africa","SSD":"_africa","STP":"_africa","SXM":"_africa","SWZ":"_africa","TCD":"_africa","TGO":"_africa","TUN":"_africa","TZA":"_africa","UGA":"_africa","ZAF":"_africa","ZMB":"_africa","ZWE":"_africa","ARE":"_asia","AFG":"_asia","ARM":"_asia","AZE":"_asia","BGD":"_asia","BHR":"_asia","BRN":"_asia","BTN":"_asia","CHN":"_asia","HKG":"_asia","CYP":"_asia","GEO":"_asia","IDN":"_asia","ISR":"_asia","IND":"_asia","IRQ":"_asia","IRN":"_asia","JOR":"_asia","JPN":"_asia","KGZ":"_asia","KHM":"_asia","PRK":"_asia","KOR":"_asia","KWT":"_asia","KAZ":"_asia","LAO":"_asia","LBN":"_asia","LKA":"_asia","MMR":"_asia","MNG":"_asia","MYS":"_asia","NCL":"_asia","NPL":"_asia","OMN":"_asia","PHL":"_asia","PAK":"_asia","QAT":"_asia","RUS":"_asia","SAU":"_asia","SGP":"_asia","SHN":"_asia","SYR":"_asia","THA":"_asia","TJK":"_asia","TLS":"_asia","TKM":"_asia","TUR":"_asia","TWN":"_asia","UZB":"_asia","VNM":"_asia","YEM":"_asia","SAU":"_middle_east","YEM":"_middle_east","TUR":"_middle_east","SYR":"_middle_east","QAT":"_middle_east","OMN":"_middle_east","LBN":"_middle_east","KWT":"_middle_east","JOR":"_middle_east","IRN":"_middle_east","IRQ":"_middle_east","ISR":"_middle_east","EGY":"_middle_east","CYP":"_middle_east","BHR":"_middle_east","ARE":"_middle_east","USA":"_north_america","TTO":"_north_america","SLV":"_north_america","PRI":"_north_america","PAN":"_north_america","NIC":"_north_america","MEX":"_north_america","JAM":"_north_america","HTI":"_north_america","GTM":"_north_america","DOM":"_north_america","CUB":"_north_america","CRI":"_north_america","CAN":"_north_america","BLZ":"_north_america","TUR":"_europe","SVK":"_europe","SVN":"_europe","SWE":"_europe","RUS":"_europe","SRB":"_europe","ROU":"_europe","PRT":"_europe","POL":"_europe","NOR":"_europe","NLD":"_europe","MKD":"_europe","MNE":"_europe","MDA":"_europe","LVA":"_europe","LUX":"_europe","LTU":"_europe","ITA":"_europe","ISL":"_europe","IRL":"_europe","HUN":"_europe","HRV":"_europe","GRC":"_europe","GBR":"_europe","FRA":"_europe","FIN":"_europe","ESP":"_europe","EST":"_europe","DNK":"_europe","DEU":"_europe","CZE":"_europe","CYP":"_europe","CHE":"_europe","BLR":"_europe","BGR":"_europe","BEL":"_europe","BIH":"_europe","AUT":"_europe","ALB":"_europe","BRA":"_south_america","VEN":"_south_america","URY":"_south_america","SUR":"_south_america","PRY":"_south_america","PER":"_south_america","GUY":"_south_america","GBR":"_south_america","ECU":"_south_america","COL":"_south_america","CHL":"_south_america","BOL":"_south_america","ARG":"_south_america","ABW":"_south_america", "IDN":"_oceania","PHL":"_oceania","NZL":"_oceania","MYS":"_oceania","AUS":"_oceania"}

#create an empty string
country=""

#loop over iso3 list
for iso3 in isolist:
    
    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            country=cname
            
    for iso,mapregion in map_dict.items(): 
        if iso==iso3: 
            mapext=mapregion
    
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'country':country, 'mapext':mapext}
    
    #Starting HTML code
    html0='''
    <!DOCTYPE html>
    <html>
    <head>
    <title>Dashboard inst</title>
    <meta http-equiv="content-type" content="text/html; charset=UTF-8">
    <script type="text/javascript" src="jquery.min.js"></script> 
    <link rel="stylesheet" type="text/css" href="/../../font-awesome-4.5.0/css/font-awesome.css">
    <link rel="stylesheet" type="text/css" href="OpenSans.css">    
    <script src="require.min.js"></script>
    <link rel="stylesheet" href="Dashboard.css">
    </head>
    
    <style>

    .left {
    margin-left:-1%;
    width:50%;
    height:100%;
    display: inline-block;
    overflow: hidden;
    }

    .right{
    height:100%;
    width:50%;
    margin-right:-2%;
    display: inline-block;
    overflow: hidden;
    }

    .frame_square {
        border:0;width:100%; height:550px;padding:2px; overflow: hidden;
        }
    
    .frame_rect {
        border:0;width:100%; height:550px;padding:2px; overflow: hidden; 
        }
        
     .frame_map {
     border:0;width:100%; height:550px;padding:2px; overflow: hidden;
     }   
    

    th, td {
       text-align:left;
       font-family:'open-sans';
        width: 50%;
      }
    </style>
    '''
    # this section is specific to each thematic do not forget to check if you have inputs right iso3 and country name as $iso3 and $country
    html='''
          <body>
        <div tabindex="-1" id="notebook" class="border-box-sizing">
        <div class="container" id="notebook-container">
        <div class="cell border-box-sizing text_cell rendered">
        <div class="inner_cell">
        <div class="text_cell_render border-box-sizing rendered_html">
        <p></p>
         <h1 id="Environnement-Institutionnel:-$country-"><span style="color:  #4381b3;  font-family:'Open Sans' !important;">Environnement Institutionnel:</span> <span style="color: #81b8e2;  font-family:'Open Sans' !important;">$country </span><a class="anchor-link" href="#Environnement-Institutionnel:-$country-">&#182;</a></h1>
        <br>
        <hr>
        <h1 ><span style="color:#A8C560;  font-family:'Open Sans' !important;">Sommaire</span></h1>
        <hr>

        <table span style="font-family:'Open Sans' !important; margin-left:40px; width:850px">
        <tr><th span style="font-family:'Open Sans' !important;">Gouvernance D&#233;mocratique et perceptions des institutions</th>
        <th span style="font-family:'Open Sans' !important;">Empowerment</th></tr><tr>
        <td span style="font-family:'Open Sans' !important;"><a href="#Perceptions-de-Corruption-dans-les-affaires-et-les-gouvernements">Corruption dans les affaires et les gouvernements</a></td>
        <td span style="font-family:'Open Sans' !important;"><a href="#Empowerment">Migration et r&#233;fugi&#233;s</a></td></tr>
        <tr><td span style="font-family:'Open Sans' !important;"><a href="#Capacit&#233;s-et-confiance-envers-les-administrations">Capacit&#233;s et confiance envers les administrations</a></td>
        <td span style="font-family:'Open Sans' !important;"><a href="#Tol&#233;reance-envers-les-minorit&#233;s">Tol&#233;reance envers les minorit&#233;s</a></td></tr><tr>
        <td span style="font-family:'Open Sans' !important;"><a href="#Satisfaction-avec-les-politiques-environnementales">Satisfaction avec les politiques environnementales</a></td>
        <td span style="font-family:'Open Sans' !important;"><a href="#Sentiment-de-s&#233;curit&#233;">Sentiment de s&#233;curit&#233;</a></td></tr><tr>
        <td span style="font-family:'Open Sans' !important;"><a href="#D&#233;penses-Militaires">D&#233;penses Militaires</a></td>
        <td ></td>
        </table>
        <br>
        <hr>


    <h1 id="Gouvernance-D&#233;mocratique-et-perceptions-des-institutions-"><span style="color:#FFA500; font-family:'Open Sans'">1. Gouvernance D&#233;mocratique et perceptions des institutions </span><a class="anchor-link" href="#Gouvernance-D&#233;mocratique-et-perceptions-des-institutions-">&#182;</a></h1>
    <h4 id="Perceptions-de-Corruption-dans-les-affaires-et-les-gouvernements" span style="font-family:'Open Sans'">Perceptions de Corruption dans les affaires et les gouvernements<a class="anchor-link" href="#Perceptions-de-Corruption-dans-les-affaires-et-les-gouvernements">&#182;</a></h4>

    <iframe src="../../dataviz/TimeSerie_Corruption%20Evolution_$iso3.html" class="frame_rect"></iframe>
    <hr>

    <div class="left">
    <iframe src="../../dataviz/map_Corruption%20in%20Government$mapext.html" class="frame_square"></iframe>
    </div>
    <div class="right">
    <iframe src="../../dataviz/map_Corruption%20Within%20Businesses$mapext.html" class="frame_square"></iframe><br>
    </div>
    <hr>

    <h3 id="Capacit&#233;s-et-confiance-envers-les-administrations"><span style="color:#FFA500; font-family:'Open Sans'">Capacit&#233;s et confiance envers les administrations</span><a class="anchor-link" href="#Capacit&#233;s-et-confiance-envers-les-administrations">&#182;</a></h3>

    <h4 id="Confiance-envers-les-institutions" span style="font-family:'Open Sans'">Confiance envers les institutions<a class="anchor-link" href="#Confiance-envers-les-institutions">&#182;</a></h4>
    <iframe src="../../dataviz/Radar_Confiance%20dans%20les%20institutions_$iso3.html" class="frame_rect"></iframe>
    
    <hr>

    <h4 id="Capacit&#233;s-Statistiques-et-temps-n&#233;cessaire-&#224;-la-cr&#233;ation-d'une-entreprise-(jours)" span style="font-family:'Open Sans'">Capacit&#233;s Statistiques et temps n&#233;cessaire &#224; la cr&#233;ation d'une entreprise (jours)<a class="anchor-link" href="#Capacit&#233;s-Statistiques-et-temps-n&#233;cessaire-&#224;-la-cr&#233;ation-d'une-entreprise-(jours)">&#182;</a></h4>

    <div class="left"><iframe src="../../dataviz/Radar_Capacit%C3%A9%20Statistiques_$iso3.html"  class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/map_IC_REG_PROC$mapext.html" class="frame_square"></iframe></div>
    <hr>

    <h4 id="Satisfaction-avec-les-politiques-environnementales" span style="font-family:'Open Sans'">Satisfaction avec les politiques environnementales<a class="anchor-link" href="#Satisfaction-avec-les-politiques-environnementales">&#182;</a></h4>

     <iframe src="../../dataviz/Radar_Satisfaction%20politique%20environnementale_$iso3.html" class="frame_rect"></iframe>
     <hr> 

     <h4 id="D&#233;penses-Militaires" span style="font-family:'Open Sans'">D&#233;penses Militaires<a class="anchor-link" href="#D&#233;penses-Militaires">&#182;</a></h4>
    <iframe src="../../dataviz/TimeSerie_MS_MIL_XPND_GD_ZS_$iso3.html" class="frame_rect"></iframe><br>       


    <h3 id="Empowerment"><span style="color:#FFA500; font-family:'Open Sans'">Empowerment </span><a class="anchor-link" href="#Empowerment">&#182;</a></h3>
    <h4 id="Migration-et-r&#233;fugi&#233;s" span style="font-family:'Open Sans'">Migration et r&#233;fugi&#233;s<a class="anchor-link" href="#Migration-et-r&#233;fugi&#233;s">&#182;</a></h4>
    <div class="left"><iframe src="../../dataviz/TimeSerie_Move%20Permanently%20to%20Another%20Country_$iso3.html"  class="frame_square"></iframe></div>
    <div class="right"><iframe src="../../dataviz/map_SM_POP_REFG$mapext.html" class="frame_square"></iframe></div>
    <hr>

    <iframe src="../../dataviz/Radar_Empowerment_$iso3.html" class="frame_rect"></iframe>
     <hr>

    <h4 id="Tol&#233;reance-envers-les-minorit&#233;s" span style="font-family:'Open Sans'">Tol&#233;reance envers les minorit&#233;s<a class="anchor-link" href="#Tol&#233;reance-envers-les-minorit&#233;s">&#182;</a></h4>
    <iframe src="../../dataviz/Radar_Tol%C3%A9reance%20envers%20les%20minorit%C3%A9s_$iso3.html" class="frame_rect" ></iframe>
    
    <hr>

    <h4 id="Sentiment-de-s&#233;curit&#233;" span style="font-family:'Open Sans'">Sentiment de s&#233;curit&#233;<a class="anchor-link" href="#Sentiment-de-s&#233;curit&#233;">&#182;</a></h4>
    <div class="left">
    <iframe src="../../dataviz/TimeSerie_Sentiment%20de%20s%C3%A9curit%C3%A9_$iso3.html" class="frame_square"></iframe></div>
    <div class="right">
    <iframe src="../../dataviz/map_Money%20Property%20Stolen$mapext.html" class="frame_square"></iframe></div>

    </div></div></div>
    </div></div>

    </body>
    </html>
    '''
    #open an handle
    with codecs.open('Dashboard'+iso3+'-inst.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = html0+Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Dashboard'+iso3+'-inst.html'

print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# ---
#
# # 3. Dashboard <span style="color: #81b8e2;"> Institution section</span>
# ![](Country_dashboard_frame/inst.png)
#
# ### 3.2 vertical v2

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
import codecs
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_inst")
#os.chdir("D:/Skydrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_inst")

#all
isolist=['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',\
         'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', \
         'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', \
         'DMA', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR', \
         'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI', 'HUN', \
         'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ITA', 'ISR', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KNA', \
         'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAF', 'MAR', 'MCO', \
         'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', \
         'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PLW', 'PNG', 'POL', \
         'PRI', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SMR', \
         'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD', 'TGO', 'THA', 'TJK', \
         'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VIR', \
         'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']

isolist=['HKG']

#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}
map_dict= {"AGO":"_africa","BFA":"_africa","BDI":"_africa","BEN":"_africa","BWA":"_africa","COD":"_africa","CAF":"_africa","COG":"_africa","CIV":"_africa","CMR":"_africa","CPV":"_africa","DJI":"_africa","DZA":"_africa","EGY":"_africa","ERI":"_africa","ETH":"_africa","GAB":"_africa","GHA":"_africa","GMB":"_africa","GIN":"_africa","GNQ":"_africa","GNB":"_africa","KEN":"_africa","COM":"_africa","LBR":"_africa","LSO":"_africa","LBY":"_africa","MAR":"_africa","MDG":"_africa","MLI":"_africa","MRT":"_africa","MUS":"_africa","MWI":"_africa","MOZ":"_africa","NAM":"_africa","NER":"_africa","NGA":"_africa","RWA":"_africa","SYC":"_africa","SDN":"_africa","SLE":"_africa","SEN":"_africa","SOM":"_africa","SSD":"_africa","STP":"_africa","SXM":"_africa","SWZ":"_africa","TCD":"_africa","TGO":"_africa","TUN":"_africa","TZA":"_africa","UGA":"_africa","ZAF":"_africa","ZMB":"_africa","ZWE":"_africa","ARE":"_asia","AFG":"_asia","ARM":"_asia","AZE":"_asia","BGD":"_asia","BHR":"_asia","BRN":"_asia","BTN":"_asia","CHN":"_asia","HKG":"_asia","CYP":"_asia","GEO":"_asia","IDN":"_asia","ISR":"_asia","IND":"_asia","IRQ":"_asia","IRN":"_asia","JOR":"_asia","JPN":"_asia","KGZ":"_asia","KHM":"_asia","PRK":"_asia","KOR":"_asia","KWT":"_asia","KAZ":"_asia","LAO":"_asia","LBN":"_asia","LKA":"_asia","MMR":"_asia","MNG":"_asia","MYS":"_asia","NCL":"_asia","NPL":"_asia","OMN":"_asia","PHL":"_asia","PAK":"_asia","QAT":"_asia","RUS":"_asia","SAU":"_asia","SGP":"_asia","SHN":"_asia","SYR":"_asia","THA":"_asia","TJK":"_asia","TLS":"_asia","TKM":"_asia","TUR":"_asia","TWN":"_asia","UZB":"_asia","VNM":"_asia","YEM":"_asia","SAU":"_middle_east","YEM":"_middle_east","TUR":"_middle_east","SYR":"_middle_east","QAT":"_middle_east","OMN":"_middle_east","LBN":"_middle_east","KWT":"_middle_east","JOR":"_middle_east","IRN":"_middle_east","IRQ":"_middle_east","ISR":"_middle_east","EGY":"_middle_east","CYP":"_middle_east","BHR":"_middle_east","ARE":"_middle_east","USA":"_north_america","TTO":"_north_america","SLV":"_north_america","PRI":"_north_america","PAN":"_north_america","NIC":"_north_america","MEX":"_north_america","JAM":"_north_america","HTI":"_north_america","GTM":"_north_america","DOM":"_north_america","CUB":"_north_america","CRI":"_north_america","CAN":"_north_america","BLZ":"_north_america","TUR":"_europe","SVK":"_europe","SVN":"_europe","SWE":"_europe","RUS":"_europe","SRB":"_europe","ROU":"_europe","PRT":"_europe","POL":"_europe","NOR":"_europe","NLD":"_europe","MKD":"_europe","MNE":"_europe","MDA":"_europe","LVA":"_europe","LUX":"_europe","LTU":"_europe","ITA":"_europe","ISL":"_europe","IRL":"_europe","HUN":"_europe","HRV":"_europe","GRC":"_europe","GBR":"_europe","FRA":"_europe","FIN":"_europe","ESP":"_europe","EST":"_europe","DNK":"_europe","DEU":"_europe","CZE":"_europe","CYP":"_europe","CHE":"_europe","BLR":"_europe","BGR":"_europe","BEL":"_europe","BIH":"_europe","AUT":"_europe","ALB":"_europe","BRA":"_south_america","VEN":"_south_america","URY":"_south_america","SUR":"_south_america","PRY":"_south_america","PER":"_south_america","GUY":"_south_america","GBR":"_south_america","ECU":"_south_america","COL":"_south_america","CHL":"_south_america","BOL":"_south_america","ARG":"_south_america","ABW":"_south_america", "IDN":"_oceania","PHL":"_oceania","NZL":"_oceania","MYS":"_oceania","AUS":"_oceania"}

#create an empty string
country=""

#loop over iso3 list
for iso3 in isolist:
    
    for cname,iso in country_dict.items(): 
        if iso==iso3: 
            country=cname
            
    for iso,mapregion in map_dict.items(): 
        if iso==iso3: 
            mapext=mapregion
    
    #What will be substitute in the template function
    Input = {'iso3':iso3, 'country':country, 'mapext':mapext}
    
    #Starting HTML code
    html='''
    <!DOCTYPE html>
    <html>
    <head>
    <title>Developpement Institutionnel</title>

    <meta http-equiv="content-type" content="text/html; charset=UTF-8">
    <script src="require.min.js"></script>
    <script src="jquery.min.js"></script>
    <link rel="stylesheet" type="text/css" href="../font-awesome-4.5.0/css/font-awesome.min.css">
    <link rel="stylesheet" type='text/css' href="../bootstrap-3.3.7-dist/css/bootstrap.min.css">
    <link rel="stylesheet" type='text/css' href="Dashboard_hztl.css">
    <link rel='stylesheet' type='text/css' href="../OpenSans.css" >
    
<style type="text/css"></style>
<script type="text/javascript">
// site preloader
timeout()
</script>
    
    
</head>

<body>
<!-- Preloader -->
 <div class="js"> 
        
 <div id="menu_theme">
     
    <div id="box1">
        <p id="rect" class="rect"></p>
        <div id="" class="parent-box">
        <i id="scale" class="fa fa-balance-scale" title="Environnement Institutionnel"></i>
            </div>
        </div>
       
    <div id="box2">
        <p id="rect2" class="rect2"></p>
        <div class="parent-box">
            <i id="cap" class="fa fa-graduation-cap" title="Developpement Humain Durable"></i>
            <i id="hos" class="fa fa-hospital-o" title="Developpement Humain Durable"></i>
            <i id="leaf" class="fa fa-leaf" title="Developpement Humain Durable"></i>
            </div>             
        </div>
          
    <div id="box3">
        <p id="rect3" class="rect3"></p>
        <div id="" class="parent-box">
            <i id="eco" class="fa fa-line-chart" title="Environnement Economique"></i>
            </div>
        </div>
     
    <div id="box4">
        <p id="rect4" class="rect4">
        <i class="fa fa-expand" id="expand" title="Ouvrir en plein &eacute;cran"></i></p>
        </div>
     
     <div id="box5">
        <p id="rect5" class="rect5">
     <i class="fa fa-chevron-left" id="nav-left" title="Reculer"></i>
         </p></div>
     
          <div id="box6">
        <p id="rect6" class="rect6">
     <i class="fa fa-chevron-right" id="nav-right" title="Avancer"></i>
         </p></div>
         
</div>
    
<div id="preloader"></div>  
     
<div class="horizontal-scroll-wrapper  rectangles" id="elementtoScrollToID">
 
<div id="test"> <!-- div to get scrolling position-->
    
    <h1><span style="color: #4381b3; margin-top:30px">Environnement Institutionnel: </span><span style="color: #81b8e2">$country</span></h1><hr style="width:900px !important; margin-left:0px;">
    <h2><span style="color:#A8C560;">Sommaire</span><hr style="width:900px !important; margin-left:0px;"></h2>
     <br><br>
        <table span style="margin-left:40px; width:850px">
          <tr>
            <th style="font-size:14px">Gouvernance D&#233;mocratique et perceptions des institutions </th>
            <th style="font-size:14px">Empowerment</th>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"id="anchorCorruption"><a href="#_">Corruption dans les affaires et le gouvernement</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorMigration">Migration et r&#233;fugi&#233;s, empowerment</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorConfAdmin">Capacit&#233;s et confiance envers les administrations</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorTolerance">Tol&#233;rance envers les minorit&#233;s</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorSatEnvir">Satisfaction avec les politiques environnementales</a></td>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorSentSec">Sentiment de s&#233;curit&#233;</a></td>
          </tr><tr>
            <td style="font-size:14px; font-weight:normal !important"><a href="#_" id="anchorDepMilitaire">D&#233;penses Militaires</a></td>
            <td style="font-size:14px; font-weight:normal !important"></td>
         
          </tr>
        </table>
    
    </div>
    
    
<div>
<h3><span style="color:#336D9D;">1. Gouvernance D&#233;mocratique et perceptions des institutions</span></h3>
<hr>
<h4>Perceptions de Corruption dans les affaires et les gouvernements</h4>
<iframe src="../dataviz/TimeSerie_Corruption%20Evolution_$iso3.html" class="frame_rect"></iframe>
</div>

<div>
<h4>Corruption dans les affaires et les gouvernements (suite</h4>
<div class="left"><iframe src="../dataviz/map_Corruption%20in%20Government$mapext.html" class="frame_map"></iframe></div>
<div class="right"><iframe src="../dataviz/map_Corruption%20Within%20Businesses$mapext.html" class="frame_map"></iframe></div>
</div>

 <div>
<h3><span style="color:#336D9D;">Capacit&#233;s et confiance envers les administrations</span></h3>   
<h4>Confiance envers les institutions</h4>
<iframe src="../dataviz/Radar_Confiance%20dans%20les%20institutions_$iso3.html" class="frame_rect"></iframe>
</div>  

<div>
<h4>Capacit&#233;s Statistiques et temps n&#233;cessaire &#224; la cr&#233;ation d'une entreprise (jours)</h4>
    <div class="left"><iframe src="../dataviz/Radar_Capacit%C3%A9%20Statistiques_$iso3.html"  class="frame_square"></iframe></div>
    <div class="right"><iframe src="../dataviz/map_IC_REG_PROC$mapext.html" class="frame_map"></iframe></div>
</div>

<div>
<h4>Satisfaction avec les politiques environnementales</h4>
<iframe src="../dataviz/Radar_Satisfaction%20politique%20environnementale_$iso3.html" class="frame_rect"></iframe><br>
</div>
    
<div>
<h4>D&#233;penses Militaires</h4>
<iframe src="../dataviz/TimeSerie_MS_MIL_XPND_GD_ZS_$iso3.html" class="frame_rect"></iframe><br>
</div>

<div>
<h3><span style="color:#336D9D;">Empowerment</span></h3>   
<h4>Migration et r&#233;fugi&#233;s</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_Move%20Permanently%20to%20Another%20Country_$iso3.html"  class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/map_SM_POP_REFG$mapext.html" class="frame_map"></iframe></div>
</div>     
   
<div> 
<h4>Emporwerment</h4>
<iframe src="../dataviz/Radar_Empowerment_$iso3.html" class="frame_rect"></iframe>
</div>

<div>
<h4>Tol&#233;reance envers les minorit&#233;s</h4>
<iframe src="../dataviz/Radar_Tol%C3%A9reance%20envers%20les%20minorit%C3%A9s_$iso3.html" class="frame_rect" ></iframe><br>
</div>
    
<div>
<h4>Sentiment de s&#233;curit&#233;</h4>
<div class="left"><iframe src="../dataviz/TimeSerie_Sentiment%20de%20sécurité_$iso3.html" class="frame_square"></iframe></div>
<div class="right"><iframe src="../dataviz/map_Money%20Property%20Stolen$mapext.html" class="frame_map"></iframe></div>
</div>
    
</div>
    </div>
</body>
</html>

    '''
    #open an handle
    with codecs.open('Dashboard'+iso3+'-inst_hztl.html', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        filename='Dashboard'+iso3+'-inst_hztl.html'

print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)
# Out:
# ******************* Job Well done ! ********************

# %% [markdown]
# # Frame Local

# %%
from string import Template
from IPython.display import HTML
import os
import winsound
os.chdir("C:/Users/rocat/OneDrive/Python/Cloud_Notebook/Country dashboard/Country_dashboard_local")

#all iso2 included the ones that have no data...
iso2list=['AL','AO','AM','AZ','BD','BJ','BO','BT','BR','BF','BU','KH','CM','CF','TD','CO','KM','CG','CD','CI','DR','EC',\
          'EG','ES','ER','ET','GA','GH','GU','GN','GY','HT','HN','IA','ID','JO','KK','KE','KY','LS','LB','MD','MW','MV',\
          'ML','MR','MX','MB','MA','MZ','NM','NP','NC','NI','NG','PK','PY','PE','PH','RW','ST','SN','SL','ZA','LK','SD',\
          'SZ','TJ','TZ','TH','GM','TL','TG','TT','TN','TR','TM','UG','UA','UZ','VN','YE','ZM','ZW']

iso2list=['AL','AM','AO','AZ','BD','BF','BJ','BO','BR','CD','CF','CG','CI','CM','CO','EG','ER','ET','GA','GH','GN','GY',\
          'HN','HT','ID','JO','KE','KH','KM','LK','LS','MA','MD','ML','MR','MV','MW','MX','MZ','NG','NI','NP','PE','PH','PK',\
          'PY','RW','SD','SL','SN','ST','SZ','TG','TH','TJ','TL','TM','TN','TR','TZ','UA','UG','UZ','VN','ZA','ZM','ZW']

## From non missing dictionnary to country specific indicator list
non_missing_dict={"AL":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "AO":"i7C3CB1,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i49B3AD0",\
                "AM":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "AZ":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "BD":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "BJ":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "BO":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "BR":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "BF":"i133C8F8,i209E190,i209E191,i349C430,i36848B0,i42FFDB2,i42FFDB4,i49B3AD0,i4E75F0A,i533BDCB,i5716309,i797B5DA,i7C3CB1,iA999FA,iC6D4E13,iCC96C1A,iCC97002,iCC973EA,iCE37FE2",\
                "KH":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "CM":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "CF":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "CO":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "KM":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "CG":"i7C3CB1,i209E190,iA999FA,i133C8F8,i36848B0,i5716309,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "CD":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "CI":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "EG":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ER":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ET":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ES":"",\
                "EC":"",\
                "GA":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "GH":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "GN":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "GY":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "HT":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "HN":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ID":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "JO":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "KE":"i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "LS":"i7C3CB1,i209E190,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "MD":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "MW":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "MV":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ML":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "MR":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "MX":"i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i42FFDB4,i209E191,i349C430,i42FFDB2",\
                "MZ":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "NP":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "NI":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "NG":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "PK":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "PY":"i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "PE":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "PH":"i7C3CB1,i209E190,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "RW":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ST":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "SN":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "SL":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ZA":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "LK":"i209E190,i533BDCB,iA999FA,i133C8F8,i5716309,i42FFDB4,i4E75F0A,i209E191,i349C430,i42FFDB2",\
                "SD":"i209E190,i533BDCB,iA999FA,i133C8F8,i5716309,i42FFDB4,i4E75F0A,i209E191,i349C430,i42FFDB2",\
                "SZ":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i42FFDB2",\
                "TJ":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "TZ":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "TH":"i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i42FFDB4,i209E191,i349C430,i42FFDB2",\
                "TL":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "TG":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "TN":"i209E190,i533BDCB,iA999FA,i133C8F8,i5716309,i42FFDB4,i4E75F0A,i209E191,i349C430,i42FFDB2",\
                "TR":"i209E190,i533BDCB,iA999FA,i133C8F8,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "TM":"i7C3CB1,i209E190,i533BDCB,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "UG":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "UA":"i7C3CB1,i209E190,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "UZ":"i7C3CB1,i209E190,iA999FA,i133C8F8,i36848B0,i5716309,i4E75F0A,i209E191,iCE37FE2,i349C430",\
                "VN":"i7C3CB1,i209E190,iA999FA,i133C8F8,i5716309,i42FFDB4,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ZM":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,i42FFDB4,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430,i42FFDB2",\
                "ZW":"i7C3CB1,i209E190,iCC96C1A,i533BDCB,i797B5DA,iC6D4E13,iA999FA,i133C8F8,i36848B0,i5716309,i49B3AD0,iCC97002,iCC973EA,i4E75F0A,i209E191,iCE37FE2,i349C430"}

ind_dict={"i7C3CB1":"Households with electricity,0,100",\
          "iA999FA":"Women with secondary or higher education,0,100",\
          "i797B5DA":"Women who are literate,0,100",\
          "i133C8F8":"Total fertility rate,0,10",\
          "i209E190":"Married women currently using any method of contraception,0,100",\
          "i209E191":"Married women currently using any modern method of contraception,0,100",\
          "i349C430":"Median age at first marriage:25-49,12,35",\
          "i36848B0":"Median age at first sexual intercourse:25-49,12,35",\
          "iCE37FE2":"Unmet need total,0,100",\
          "i42FFDB2":"Infant mortality rate,0,300",\
          "i42FFDB4":"Under-five mortality rate,0,300",\
          "i49B3AD0":"Place of delivery: Health facility,0,100",\
          "i4E75F0A":"Received all vaccinations,0,100",\
          "i533BDCB":"Treatment of diarrhea: Either ORS or RHS,0,100",\
          "i5716309":"Median duration of exclusive breastfeeding,0,100",\
          "iCC96C1A":"Children stunted,0,100",\
          "iCC97002":"Children underweight,0,100",\
          "iCC973EA":"Children wasted,0,100",\
          "i42759491":"Men receiving an HIV test and receiving test results in the last 12 months,0,100",\
          "i42759492":"Women receiving an HIV test and receiving test results in the last 12 months,0,100",\
          "i41075E91":"HIV prevalence among men,0,100",\
          "i41075E92":"HIV prevalence among women,0,100",\
          "i41075E93":"HIV prevalence among general population,0,100",\
          "iC6D4E13":"Children under 5 who slept under an insecticide treated net,0,100"}

#create dictionnary that associate country name to iso3 code
country_dict = {"Arab World":"ARB", "Central Europe and the Baltics":"CEB", "Caribbean small states":"CSS", "East Asia & Pacific":"EAP", "East Asia & Pacific (all income levels)":"EAS", "Europe & Central Asia":"ECA", "Europe & Central Asia (all income levels)":"ECS", "Euro area":"EMU", "European Union":"EUU", "Fragile and conflict affected situations":"FCS", "High income":"HIC", "Heavily indebted poor countries (HIPC)":"HPC", "Latin America & Caribbean":"LAC", "Latin America & Caribbean (all income levels)":"LCN", "Least developed countries: UN classification":"LDC", "Low income":"LIC", "Lower middle income":"LMC", "Low & middle income":"LMY", "Middle East & North Africa (all income levels)":"MEA", "Middle income":"MIC", "Middle East & North Africa":"MNA", "North America":"NAC", "High income: nonOECD":"NOC", "High income: OECD":"OEC", "OECD members":"OED", "Other small states":"OSS", "Pacific island small states":"PSS", "South Asia":"SAS", "Sub-Saharan Africa":"SSA", "Sub-Saharan Africa (all income levels)":"SSF", "Small states":"SST", "Upper middle income":"UMC", "World":"WLD","Cote d'Ivoire":"CIV","Curacao":"CUW","Sao Tome and Principe":"STP","American Samoa":"ASM","Australia":"AUS","Brunei Darussalam":"BRN","China":"CHN","Fiji":"FJI","Micronesia, Fed. Sts.":"FSM","Guam":"GUM","Hong Kong SAR, China":"HKG","Indonesia":"IDN","Japan":"JPN","Cambodia":"KHM","Kiribati":"KIR","Korea, Rep.":"KOR","Lao PDR":"LAO","Macao SAR, China":"MAC","Marshall Islands":"MHL","Myanmar":"MMR","Mongolia":"MNG","Northern Mariana Islands":"MNP","Malaysia":"MYS","New Caledonia":"NCL","New Zealand":"NZL","Philippines":"PHL","Palau":"PLW","Papua New Guinea":"PNG","Korea, Dem. Rep.":"PRK","French Polynesia":"PYF","Singapore":"SGP","Solomon Islands":"SLB","Thailand":"THA","Timor-Leste":"TLS","Tonga":"TON","Tuvalu":"TUV","Taiwan, China":"TWN","Vietnam":"VNM","Vanuatu":"VUT","Samoa":"WSM","Albania":"ALB","Andorra":"AND","Armenia":"ARM","Austria":"AUT","Azerbaijan":"AZE","Belgium":"BEL","Bulgaria":"BGR","Bosnia and Herzegovina":"BIH","Belarus":"BLR","Switzerland":"CHE","Channel Islands":"CHI","Cyprus":"CYP","Czech Republic":"CZE","Germany":"DEU","Denmark":"DNK","Spain":"ESP","Estonia":"EST","Finland":"FIN","France":"FRA","Faeroe Islands":"FRO","United Kingdom":"GBR","Georgia":"GEO","Greece":"GRC","Greenland":"GRL","Croatia":"HRV","Hungary":"HUN","Isle of Man":"IMN","Ireland":"IRL","Iceland":"ISL","Italy":"ITA","Kazakhstan":"KAZ","Kyrgyz Republic":"KGZ","Liechtenstein":"LIE","Lithuania":"LTU","Luxembourg":"LUX","Latvia":"LVA","Monaco":"MCO","Moldova":"MDA","Macedonia, FYR":"MKD","Montenegro":"MNE","Netherlands":"NLD","Norway":"NOR","Poland":"POL","Portugal":"PRT","Romania":"ROU","Russian Federation":"RUS","San Marino":"SMR","Serbia":"SRB","Slovak Republic":"SVK","Slovenia":"SVN","Sweden":"SWE","Tajikistan":"TJK","Turkmenistan":"TKM","Turkey":"TUR","Ukraine":"UKR","Uzbekistan":"UZB","Aruba":"ABW","Argentina":"ARG","Antigua and Barbuda":"ATG","Bahamas, The":"BHS","Belize":"BLZ","Bolivia":"BOL","Brazil":"BRA","Barbados":"BRB","Chile":"CHL","Colombia":"COL","Costa Rica":"CRI","Cuba":"CUB","Curaçao":"CUW","Cayman Islands":"CYM","Dominica":"DMA","Dominican Republic":"DOM","Ecuador":"ECU","Grenada":"GRD","Guatemala":"GTM","Guyana":"GUY","Honduras":"HND","Haiti":"HTI","Jamaica":"JAM","St. Kitts and Nevis":"KNA","St. Lucia":"LCA","St. Martin (French part)":"MAF","Mexico":"MEX","Nicaragua":"NIC","Panama":"PAN","Peru":"PER","Puerto Rico":"PRI","Paraguay":"PRY","El Salvador":"SLV","Suriname":"SUR","Sint Maarten (Dutch part)":"SXM","Turks and Caicos Islands":"TCA","Trinidad and Tobago":"TTO","Uruguay":"URY","St. Vincent and the Grenadines":"VCT","Venezuela, RB":"VEN","Virgin Islands (U.S.)":"VIR","United Arab Emirates":"ARE","Bahrain":"BHR","Djibouti":"DJI","Algeria":"DZA","Egypt, Arab Rep.":"EGY","Iran, Islamic Rep.":"IRN","Iraq":"IRQ","Israel":"ISR","Jordan":"JOR","Kuwait":"KWT","Lebanon":"LBN","Libya":"LBY","Morocco":"MAR","Malta":"MLT","Oman":"OMN","West Bank and Gaza":"PSE","Qatar":"QAT","Saudi Arabia":"SAU","Syrian Arab Republic":"SYR","Tunisia":"TUN","Yemen, Rep.":"YEM","Bermuda":"BMU","Canada":"CAN","United States":"USA","Afghanistan":"AFG","Bangladesh":"BGD","Bhutan":"BTN","India":"IND","Sri Lanka":"LKA","Maldives":"MDV","Nepal":"NPL","Pakistan":"PAK","Angola":"AGO","Burundi":"BDI","Benin":"BEN","Burkina Faso":"BFA","Botswana":"BWA","Central African Republic":"CAF","Cote d'Ivoire":"CIV","Cameroon":"CMR","Congo, Dem. Rep.":"COD","Congo, Rep.":"COG","Comoros":"COM","Cabo Verde":"CPV","Eritrea":"ERI","Ethiopia":"ETH","Gabon":"GAB","Ghana":"GHA","Guinea":"GIN","Gambia, The":"GMB","Guinea-Bissau":"GNB","Equatorial Guinea":"GNQ","Kenya":"KEN","Liberia":"LBR","Lesotho":"LSO","Madagascar":"MDG","Mali":"MLI","Mozambique":"MOZ","Mauritania":"MRT","Mauritius":"MUS","Malawi":"MWI","Namibia":"NAM","Niger":"NER","Nigeria":"NGA","Rwanda":"RWA","Sudan":"SDN","Senegal":"SEN","Sierra Leone":"SLE","Somalia":"SOM","South Sudan":"SSD","São Tomé and Principe":"STP","Swaziland":"SWZ","Seychelles":"SYC","Chad":"TCD","Togo":"TGO","Tanzania":"TZA","Uganda":"UGA","South Africa":"ZAF","Zambia":"ZMB","Zimbabwe":"ZWE"}

gps_dict={"AL":"ALB,41.1533,20.1683,7", "AO":"AGO,-11.2027,17.8739,5", "AM":"ARM,40.0691,45.0382,7", "AZ":"AZE,40.1431,47.5769,7",\
          "BD":"BGD,23.685,90.3563,7", "BJ":"BEN,9.30769,2.31583,6", "BO":"BOL,-16.2902,-63.5887,5", "BT":"BTN,27.5142,90.4336,8",\
          "BR":"BRA,-14.235,-51.9253,4", "BF":"BFA,12.2383,-1.56159,6", "BU":"null,-32.87,26.12,6", "KH":"KHM,12.5657,104.991, 7",\
          "CM":"CMR,7.36972,12.3547, 5", "CF":"CAF,6.61111,20.9394,6", "TD":"TCD,15.4542,18.7322,5", "CO":"COL,4.57087,-74.2973,5",\
          "KM":"COM,-11.875,43.8722,8", "CG":"COG,-0.228021,15.8277,6", "CD":"COD,-4.03833,21.7587,5", "CI":"CIV,7.53999,-5.54708,6",\
          "DR":"null,-32.87,26.12,7", "EC":"ECU,-1.83124,-78.1834,6", "EG":"EGY,26.8206,30.8025,5", "ES":"ESP,40.4637,-3.74922,6",\
          "ER":"ERI,15.1794,39.7823,7", "ET":"ETH,9.145,40.4897,5", "GA":"GAB,-0.803689,11.6094,6", "GH":"GHA,7.94653,-1.02319,6",\
          "GU":"GUM,13.4443,144.794,9", "GN":"GIN,9.94559,-9.69664,6", "GY":"GUY,4.86042,-58.9302,6", "HT":"HTI,18.9712,-72.2852,8",\
          "HN":"HND,15.2,-86.2419,7", "IA":"null,-32.87,26.12,7", "ID":"IDN,-0.789275,113.921,4", "JO":"JOR,30.5852,36.2384,7",\
          "KK":"null,-32.87,26.12,7", "KE":"KEN,-0.023559,37.9062,6", "KY":"CYM,19.5135,-80.567,9", "LS":"LSO,-29.61,28.2336,8",\
          "LB":"LBN,33.8547,35.8623,8", "MD":"MDA,47.4116,28.3699,7", "MW":"MWI,-13.2543,34.3015,6", "MV":"MDV,3.20278,73.2207,7",\
          "ML":"MLI,17.5707,-3.99617,5", "MR":"MRT,21.0079,-10.9408,5", "MX":"MEX,23.6345,-102.553,5", "MB":"null,-32.87,26.12,7",\
          "MA":"MAR,31.7917,-7.09262,5", "MZ":"MOZ,-18.6657,35.5296,5", "NM":"null,-32.87,26.12,7", "NP":"NPL,28.3949,84.124,7",\
          "NC":"NCL,-20.9043,165.618,7", "NI":"NIC,12.8654,-85.2072,7", "NG":"NGA,9.082,8.67528,6", "PK":"PAK,30.3753,69.3451,5",\
          "PY":"PRY,-23.4425,-58.4438,6", "PE":"PER,-9.18997,-75.0152,5", "PH":"PHL,12.8797,121.774,5", "RW":"RWA,-1.94028,29.8739,8",\
          "ST":"STP,0.18636,6.61308,8", "SN":"SEN,14.4974,-14.4524,7", "SL":"SLE,8.46056,-11.7799,7", "ZA":"ZAF,-30.5595,22.9375,5",\
          "LK":"LKA,7.87305,80.7718,7", "SD":"SDN,12.8628,30.2176,5", "SZ":"SWZ,-26.5225,31.4659,8", "TJ":"TJK,38.861,71.2761,6",\
          "TZ":"TZA,-6.36903,34.8888,5", "TH":"THA,15.87,100.993,5", "GM":"GMB,13.4432,-15.3101,8", "TL":"TLS,-8.87422,125.728,8",\
          "TG":"TGO,8.61954,0.824782,7", "TT":"TTO,10.6918,-61.2225,8", "TN":"TUN,33.8869,9.5375,6", "TR":"TUR,38.9637,35.2433,6",\
          "TM":"TKM,38.9697,59.5563,7", "UG":"UGA,1.37333,32.2903,7", "UA":"UKR,48.3794,31.1656,6", "UZ":"UZB,41.3775,64.5853,6",\
          "VN":"VNM,14.0583,108.277,5", "YE":"YEM,15.5527,48.5164,6", "ZM":"ZMB,-13.1339,27.8493,6", "ZW":"ZWE,-19.0154,29.1549,6"}

country=""

for iso2 in iso2list:
    for iso,non_miss in non_missing_dict.items():
        if iso==iso2:
            li_left=[]
            li_right=[]
            linklist=[]
            item=non_miss.split(',')
            nb_non_miss=len(item)
            mid=round(nb_non_miss/2)
            
            vars()['list_'+str(iso)]=item
            for i in range(0,nb_non_miss): 
                for x,y in ind_dict.items(): 
                    info=y.split(',')
                    definition=info[0]
                    if x==item[i]: 
                        linklist.append('$("#link'+str(i)+'").click(function(e) {e.preventDefault(); $("#frame").html("<iframe src=*http://afd.countrydashboards.com/dataviz/local/Map_'+str(item[i])+'_'+iso2+'.html* width=*100%* height=*100%* frameborder=*0*></iframe>");});')
                        if i<mid:
                            li_left.append('<li><a href="" id="link'+str(i)+'">'+str(definition)+'</a></li>')
                        if i>=mid:
                            li_right.append('<li><a href="" id="link'+str(i)+'">'+str(definition)+'</a></li>')
                            
            li_left=''.join(map(str,li_left))
            li_right=''.join(map(str,li_right))
            linklist=''.join(map(str,linklist))
            linklist=linklist.replace("*", "'")

    for isoL,info in gps_dict.items():
        if isoL==iso2:
            item=info.split(',')
            iso3=item[0]
           
                
    for cname,isoL in country_dict.items():
        if isoL==iso3:
            country=cname
            
    print(iso3, country)
    #What will be substitute in the template function
    Input = {'iso2':iso2,'iso3':iso3,'country':country, 'linklist':linklist,'li_right':li_right, 'li_left':li_left}
    
    #Starting HTML code
    html0='''
    <!DOCTYPE html>
    <html>
    <head><meta charset="UTF-8" />
    <title>DHS</title>
   
    <link rel="stylesheet" href="Dashboard.css" />
    
    </head>
    <body>
      <div tabindex="-1" id="notebook" class="border-box-sizing">
        <div class="container" id="notebook-container">

    <div class="cell border-box-sizing text_cell rendered">
    <div class="prompt input_prompt">
    </div>
    <div class="inner_cell">
    <div class="text_cell_render border-box-sizing rendered_html">
          <script type='text/javascript' src='jquery.min.js'></script>
              <script src="require.min.js"></script>
    <link rel="stylesheet" type="text/css" href="../../font-awesome-4.5.0/css/font-awesome.min.css">
    <link rel='stylesheet' type='text/css' href="../../OpenSans.css" >
    <style>
    
       ul {
          list-style: none !important; 
          margin: 0;
          padding: 0;
          background-color: none;
          font-size:11px;
          font-family: 'Today SB', 'Open Sans', 'Helvetica', arial, sans-serif;
          /*font-weight:bold;*/
        }

        li a {
          display: block;
          color: #000;
          padding: 1px 1px;
          text-decoration: none;
        }

        li a.active {
          background-color: #649CCB;
          color: white;     
        }

        li a:hover:not(.active) {
          background-color: #555;
          color: white;
        }

        .frame_css {
          width: 820px;
          height: 525px;
          margin-left: 20px;
          margin-top: 285px;
        }
        
        .menu_left_css {
          margin-top: 10px;
          display:block; float:left; 
          width:450px; 
        }
        .menu_right_css {
          margin-top: 10px;
          margin-right:65px;
          display:block; float:right; 
          width:450px; 
        }
        
        a {
        text-decoration: none !important;
        }

        a:visited {
            color: black;
        }
        
        a:hover {
            color: #8ad3f7 !important
        }
    </style>
    
    '''
    # this section is specific to each thematic do not forget to check if you have inputs right iso3 and country name as $iso3 and $country
    html='''
    <script type='text/javascript'>
    
    window.onload=function(){
        $('#frame').html('<iframe src="http://afd.countrydashboards.com/dataviz/local/Map_i42FFDB4_$iso2.html"  width="100%" height="100%" frameborder="0"></iframe>');
        $linklist
            }
            
    </script>

    </head>
    <body>
      <hr><h1>
      <span style="color: #336D9D;">Données infranationales:</span><span style="color:#82b5e0;"> $country </span>
      <a href="http://afd.countrydashboards.com/dataviz/local/data_$iso2.csv" target="_blank" style="font-size:11px; color:#336D9D; font-family:Open Sans; float:right;" > | Download data <i class="fa fa-cloud-download" aria-hidden="true"></i><a href="http://afd.countrydashboards.com/dataviz/local/DHSDefinition.html" target="_blank" style="font-size:11px; color:#336D9D; font-family:Open Sans; float:right;">Définition des indicateurs <big><i class="fa fa-file-code-o" aria-hidden="true"></i></big></a>
       </h1><hr>
   
   <div id="menu" class="menu_left_css">
     <ul>
      <li><a class="active" href="#home"></big><big>Demographic Health Surveys (DHS)</big></big></a></li>
          $li_left

    </ul>
    </div>
    <div id="menu" class="menu_right_css">
     <ul>
      <li><a class="active" href="#home"></big><big> &nbsp;</big></big> </a></li>
            $li_right
            
    </ul>
    </div>
    <div id="frame" class="frame_css">
    </div>

    </body>
    </html>

    '''
    #open an handle
    with codecs.open('Country_dashboard_local'+iso3+', "w", "utf-8-sig") as f:
        #write the content within the handle
        file_content = html0+Template(html).safe_substitute(Input)
        f.write(file_content)
        f.close()
        #generate an html file
        #filename='Dashboard_local'+iso3+'.html'
                                        
                 
print("\n******************* Job Well done ! ********************\n")
winsound.PlaySound("SystemExit", winsound.SND_ALIAS)

# %% [markdown]
# ### Test if web page dataviz exist

# %%
import requests
request = requests.get('http://afd.countrydashboards.com/Map/GDPsubDZA.html')
if request.status_code == 200:
    print('Web site exists')
else:
    print('Web site does not exist')
